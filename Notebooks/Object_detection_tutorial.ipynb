# %% [markdown]
# #   ROS2 | Exercise 4 - Computer Vision
#
# ##  Task 3 - Object Detection
#
# ### Pre-requisites
# Before you begin this Notebook you have to complete the following tasks explained in the handout
# - [x] Setting up the gazebo simulation as a ROS package
# - [x] Setting up Conda environment to run this jupyter notebook
#
# ### Introduction
# Object detection and its importance in robotics. Opencv Intro. Some images
#
# There are 3 parts in this Notebook which covers the following
#    - 3.1 : Basic Image processing and Opencv contour detection
#    - 3.2 : Object detection and Tracking with Video
#    - 3.3 : Object detection and Tracking with ROS2

# %% [markdown]
# ***
# ### 3.1 Basic Image processing with OpenCV
#
# ### 3.1.1
# Familiarize yourself with the basic functionalities available in openCV for basic image reading and visualization with this reference [link](https://docs.opencv.org/4.x/db/deb/tutorial_display_image.html). It has both C++ & Python code. We are following python in this notebook. Execute the following code that reads an image file and displays it in an opencv window.

# %%
import imutils
import cv2
import numpy as np

frame = cv2.imread('image.png')
cv2.imshow("Tracking",frame)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.2
#
# It is important to  pre-process raw input images in computer vision tasks such as object detection and tracking. OpenCV imgproc module contains several functionalities which are often used in image processing.
#
# Convertion between color spaces is necessary to generate image masks. Execute and observe the following code where you convert an image from RGB to HSV color space. The code generates a mask of the green color object.
#
# **Your task**
#
# - [ ] Change HSV values in order to generate masks of other objects.
#
# **References**
# - [Concept of HSL and HSV Color spaces](https://en.wikipedia.org/wiki/HSL_and_HSV)
# - [Opencv basic Image processing functionalities](https://docs.opencv.org/4.x/d7/da8/tutorial_table_of_content_imgproc.html)
# - [OpenCV RGB-HSV color converstions documentation](https://docs.opencv.org/3.4.6/de/d25/imgproc_color_conversions.html#color_convert_rgb_hsv)

# %%
# lower and upper boundaries for HSV thresholds
#Lower = (29, 86, 64)
#Upper = (64, 255, 255)

Lower = (29, 86, 64)
Upper = (255, 255, 255)
kernel = np.ones((11,11),np.float32)/25

    

def prep(frame):
    frame = imutils.resize(frame, width=600)
    kernel = np.ones((11, 11), np.uint8)

    ## Todo 3.1.3 gaussian blur
    # blurred =
    blurred = cv2.GaussianBlur(frame, (11,11), 0)
    
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv,Lower,Upper)

    ## Todo 3.1.3 gaussian blur
    mask = cv2.erode(mask, kernel, iterations=0)

    mask = cv2.dilate(mask, kernel, iterations=0)
    return mask, frame

mask,frame = prep(frame)

cv2.imshow("Image",frame)
cv2.imshow("Masked Image",mask)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.3
#
# The above implementation provides a satisfactory result. However, when dealing with noisy images it is important to perform morphological transformations such as smoothing, erotion and dialation to get better results.
#
# **Your task**
#
# Read the following documentations and implement the following transformations inside the prep_frame() function above.
#
#
# - [ ] Apply Gaussian blur with a kernel size of 11x11
# - [ ] Apply erosion
# - [ ] Apply dialation
#
# **References**
#
# - [Smoothing Images with OpenCV](https://docs.opencv.org/4.5.2/d4/d13/tutorial_py_filtering.html)
# - [Perform Erosion and Dialation on the image mask using OpenCV](https://docs.opencv.org/3.4/db/df6/tutorial_erosion_dilatation.html)

# %% [markdown]
# ### 3.1.4
#
# Finding contours in an image is useful in object detection and tracking. The code snippet below extracts contours from the image file and draws a circle with its center as the same center of detected contour. Execute the code below and observe the results.
#
# **References**
# - [ Detecting contours with OpenCV](https://docs.opencv.org/4.5.0/d4/d73/tutorial_py_contours_begin.html)

# %%
### Find contours and display
def find_cnts(mask):
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    return cnts
def detect_conts(frame):
    mask,frame = prep(frame)
    cnts = find_cnts(mask)
    c = max(cnts, key=cv2.contourArea)
    ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?

    # Find center of contour using moments in opencvq
    M = cv2.moments(c)
    center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

    #circle
    frame1 = frame
    cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
    cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
    #cv2.imshow("Circle", frame1)


    ## ToDo 3.1.5 
    #  1. Bounding rectancgle

    # Loop over the contours
    for c in cnts:
        # Get the bounding rectangle of the contour
        x, y, w, h = cv2.boundingRect(c)
        # Draw the bounding rectangle on the image
        cv2.rectangle(frame1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Get the rotated bounding rectangle of the contour
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        # Draw the rotated bounding rectangle on the image

        cv2.drawContours(frame1, [box], 0, (0, 0, 255), 2)

        hull = cv2.convexHull(c)
        # Draw the convex hull on the image
        cv2.drawContours(frame1, [hull], 0, (255, 0, 0), 2)


    # Show the image with the bounding rectangles
    cv2.imshow("Bounding Rectangles", frame1)


    #  2. Convex Hull
    return frame1

def draw_conts(frame):
    mask,frame = prep(frame)
    cnts = find_cnts(mask)
    c = max(cnts, key=cv2.contourArea)
    ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?

    # Find center of contour using moments in opencvq
    M = cv2.moments(c)
    center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

    #circle
    frame1 = frame
    cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
    cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
    #cv2.imshow("Circle", frame1)


    ## ToDo 3.1.5 
    #  1. Bounding rectancgle

    # Loop over the contours
    for c in cnts:
        # Get the bounding rectangle of the contour
        x, y, w, h = cv2.boundingRect(c)
        # Draw the bounding rectangle on the image
        cv2.rectangle(frame1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Get the rotated bounding rectangle of the contour
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        # Draw the rotated bounding rectangle on the image

        cv2.drawContours(frame1, [box], 0, (0, 0, 255), 2)

        hull = cv2.convexHull(c)
        # Draw the convex hull on the image
        cv2.drawContours(frame1, [hull], 0, (255, 0, 0), 2)


    # Show the image with the bounding rectangles
    cv2.imshow("Bounding Rectangles", frame1)


    #  2. Convex Hull


    cv2.waitKey(0) & 0xFF
    cv2.destroyAllWindows()

frame = cv2.imread('image.png')
draw_conts(frame)
# Out:
# /tmp/ipykernel_97099/763091239.py:83: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)

# %% [markdown]
# ### 3.1.5
# The above implementation only uses a minimum enclosing circle for labelling the detected image. There are more labelling options such as bounding boxes and convex hull which may come handy in various computer vision tasks.
#
# **Your task**
#
# - [ ] Implement a bounding rectangle and rotated rectangle on the detected contours by modifying the code in 3.1.4
# - [ ] Implement a convex hull on the detected contours by modifying the code in 3.1.4
#
# **References**
# - [Contour features in OpenCV](https://docs.opencv.org/4.x/dd/d49/tutorial_py_contour_features.html)
# - [Creating Bounding boxes and circles for contours](https://docs.opencv.org/4.x/da/d0c/tutorial_bounding_rects_circles.html)
# -[Convex Hull](https://docs.opencv.org/4.x/d7/d1d/tutorial_hull.html)

# %% [markdown]
# ***
# ### 3.2 Object detection and Tracking with Video
#
# ### 3.2.1
#
# Execute and observe the below code snippet which reads frames from a given video file at a pre-defined frame rate.
#
# **Your task**
# - [ ] Implement pre-processing and find contour of the moving blob on by modifiying the same code below
# - [ ] Implement a suitable labelling mode (Enclosed Circle / bounding Box or convex hull) and display the resulted tracking on a seperated window
#
# **Tip** : Use the same functions from 3.1. Avoid creating duplicate functions and unnecessarily lenghty code

# %%
from imutils.video import VideoStream
import time

vs = cv2.VideoCapture("test_video.avi")
time.sleep(2.0)

frame_rate = 30
prev = 0

while True :
    time_elapsed = time.time() - prev

    
    if time_elapsed > 1./frame_rate:
        frame = vs.read()
        frame = frame[1]
        draw_conts(frame)
        if frame is None:
            break
        cv2.imshow("Frame", frame)
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            break
        prev = time.time()
            
cv2.destroyAllWindows()
# Out:
# /tmp/ipykernel_93244/3853825719.py:38: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)

# %% [markdown]
# ---
#
# ###  3.3 Object detection and Tracking with ROS2
#
# ### 3.3.1
#
# In applications concerning robotic perception, so often visual data are obtained via camera sensors interfaced with ros. In this section you are provided with a ros-ignition simulation package which publish camera sensor data. The code snippet below subscribes to the camera sensor data and stream on to an OpenCV window.
#
# Assuming you have successfully build the package on your system using the instructions from handout, Open a New shell in you terminal and launch the simulation.
#
# ```
# $ source /opt/ros/foxy/setup.bash
# $ cd ~/ws
# $ source install/setup.bash
# $ ros2 launch walking_actor cam_world.launch.py
# ```
#
# While the simulation is running in background , run the code snippet below and observe the result
#
# - To close the cv2 window , select the window and press 'q'
# - To stop the execution of code snippet, double press on 'i' in keyboard or interrupt the kernel from menu
#
#
# **Your task**
#
# - [ ] Modify the python code to track the walking actor. You can use any feature of the actor to track.
# - [ ] Display the tracking in a seperate cv2 window
#
#
# **References**
# - [ROS2 python subscriber/publisher](https://docs.ros.org/en/foxy/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Publisher-And-Subscriber.html)
# - [rclpy API Documentation](https://docs.ros2.org/foxy/api/rclpy/api/execution_and_callbacks.html#module-rclpy.executors)

# %%
import sys
import rclpy
import imutils

from rclpy.node import Node
from cv_bridge import CvBridge
import numpy as np
import cv2
from sensor_msgs.msg import Image, CameraInfo
#print(sys.path)


# lower and upper boundaries for HSV thresholds
#Lower = (29, 86, 64)
#Upper = (64, 255, 255)

Lower = (29, 86, 64)
Upper = (255, 255, 255)
kernel = np.ones((11,11),np.float32)/25

    

def prep(frame):
    frame = imutils.resize(frame, width=600)
    kernel = np.ones((11, 11), np.uint8)

    ## Todo 3.1.3 gaussian blur
    # blurred =
    blurred = cv2.GaussianBlur(frame, (11,11), 0)
    
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv,Lower,Upper)

    ## Todo 3.1.3 gaussian blur
    mask = cv2.erode(mask, kernel, iterations=0)

    mask = cv2.dilate(mask, kernel, iterations=0)
    return mask, frame


### Find contours and display
def find_cnts(mask):
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    return cnts
def detect_conts(frame):
    mask,frame = prep(frame)
    cnts = find_cnts(mask)
    c = max(cnts, key=cv2.contourArea)
    ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?

    # Find center of contour using moments in opencvq
    M = cv2.moments(c)
    center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

    #circle
    frame1 = frame
    cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
    cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
    #cv2.imshow("Circle", frame1)


    ## ToDo 3.1.5 
    #  1. Bounding rectancgle

    # Loop over the contours
    for c in cnts:
        # Get the bounding rectangle of the contour
        x, y, w, h = cv2.boundingRect(c)
        # Draw the bounding rectangle on the image
        cv2.rectangle(frame1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Get the rotated bounding rectangle of the contour
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        # Draw the rotated bounding rectangle on the image

        cv2.drawContours(frame1, [box], 0, (0, 0, 255), 2)

        hull = cv2.convexHull(c)
        # Draw the convex hull on the image
        cv2.drawContours(frame1, [hull], 0, (255, 0, 0), 2)


    # Show the image with the bounding rectangles
    #cv2.imshow("Bounding Rectangles", frame1)


    #  2. Convex Hull
    return frame1

bridge = CvBridge()

class Get_Images(Node):

    def __init__(self):
        # Initialize the node
        super().__init__('Image_Subscriber')
        # Initialize the subscriber
        self.subscription_ = self.create_subscription( Image,'/camera', self.listener_callback,10)
        self.subscription_  # prevent unused variable warning
        timer_period = 0.1  # seconds
        self.timer = self.create_timer(timer_period, self.timer_callback)
        self.K = True

    def listener_callback(self, msg):
        height = msg.height
        width = msg.width
        channel = msg.step//msg.width
        #frame = np.reshape(msg.data, (height, width, channel))
        self.frame =  bridge.imgmsg_to_cv2(msg, desired_encoding='bgr8')
        self.get_logger().info("Image Received")
        return self.frame
    
    def timer_callback(self):
        if self.K == True:
            #cv2.imshow("Tracking",self.frame)
            cv2.imshow("Tracking",detect_conts(self.frame))
            key = cv2.waitKey(1) & 0xFF
            if key == ord("q"):
                self.get_logger().info('Closing stream window..')
                self.K = False
                cv2.destroyAllWindows()
        
                
    def stop_stream(self):
        self.get_logger().info('Stopping the stream ...')
        

try:
    
    rclpy.init(args=None)
    image_subscriber = Get_Images()
    rclpy.spin(image_subscriber)

except KeyboardInterrupt:
    # executes on keyboard kernal interrupt with double pressing button "i"
    image_subscriber.stop_stream()
    image_subscriber.destroy_node()
    rclpy.shutdown()
# Out:
# [INFO] [1672660343.201519355] [Image_Subscriber]: Image Received
# /tmp/ipykernel_98276/2085606676.py:76: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)
# [INFO] [1672660343.357558854] [Image_Subscriber]: Image Received
# [INFO] [1672660343.430293758] [Image_Subscriber]: Image Received
# [INFO] [1672660343.494961412] [Image_Subscriber]: Image Received
# [INFO] [1672660343.539847146] [Image_Subscriber]: Image Received
# [INFO] [1672660343.599119842] [Image_Subscriber]: Image Received
# [INFO] [1672660343.633820821] [Image_Subscriber]: Image Received
# [INFO] [1672660343.704989033] [Image_Subscriber]: Image Received
# [INFO] [1672660343.740885707] [Image_Subscriber]: Image Received
# [INFO] [1672660343.795668676] [Image_Subscriber]: Image Received
# [INFO] [1672660343.816355143] [Image_Subscriber]: Image Received
# [INFO] [1672660343.852474511] [Image_Subscriber]: Image Received
# [INFO] [1672660343.906049127] [Image_Subscriber]: Image Received
# [INFO] [1672660343.928535827] [Image_Subscriber]: Image Received
# [INFO] [1672660343.973171962] [Image_Subscriber]: Image Received
# [INFO] [1672660344.014610037] [Image_Subscriber]: Image Received
# [INFO] [1672660344.091174895] [Image_Subscriber]: Image Received
# [INFO] [1672660344.131635856] [Image_Subscriber]: Image Received
# [INFO] [1672660344.191611392] [Image_Subscriber]: Image Received
# [INFO] [1672660344.238873303] [Image_Subscriber]: Image Received
# [INFO] [1672660344.290660820] [Image_Subscriber]: Image Received
# [INFO] [1672660344.353999287] [Image_Subscriber]: Image Received
# [INFO] [1672660344.419576579] [Image_Subscriber]: Image Received
# [INFO] [1672660344.480915140] [Image_Subscriber]: Image Received
# [INFO] [1672660344.540217887] [Image_Subscriber]: Image Received
# [INFO] [1672660344.595613894] [Image_Subscriber]: Image Received
# [INFO] [1672660344.674856163] [Image_Subscriber]: Image Received
# [INFO] [1672660344.729467771] [Image_Subscriber]: Image Received
# [INFO] [1672660344.788578229] [Image_Subscriber]: Image Received
# [INFO] [1672660344.827532423] [Image_Subscriber]: Image Received
# [INFO] [1672660344.912216028] [Image_Subscriber]: Image Received
# [INFO] [1672660344.994122062] [Image_Subscriber]: Image Received
# [INFO] [1672660345.049698619] [Image_Subscriber]: Image Received
# [INFO] [1672660345.112943332] [Image_Subscriber]: Image Received
# [INFO] [1672660345.177374006] [Image_Subscriber]: Image Received
# [INFO] [1672660345.227079254] [Image_Subscriber]: Image Received
# [INFO] [1672660345.268880203] [Image_Subscriber]: Image Received
# [INFO] [1672660345.328461919] [Image_Subscriber]: Image Received
# [INFO] [1672660345.402458893] [Image_Subscriber]: Image Received
# [INFO] [1672660345.442628799] [Image_Subscriber]: Image Received
# [INFO] [1672660345.508412069] [Image_Subscriber]: Image Received
# [INFO] [1672660345.571831505] [Image_Subscriber]: Image Received
# [INFO] [1672660345.648554245] [Image_Subscriber]: Image Received
# [INFO] [1672660345.696332890] [Image_Subscriber]: Image Received
# [INFO] [1672660345.763683263] [Image_Subscriber]: Image Received
# [INFO] [1672660345.814903823] [Image_Subscriber]: Image Received
# [INFO] [1672660345.865283713] [Image_Subscriber]: Image Received
# [INFO] [1672660345.914299965] [Image_Subscriber]: Image Received
# [INFO] [1672660345.975801761] [Image_Subscriber]: Image Received
# [INFO] [1672660346.036633471] [Image_Subscriber]: Image Received
# [INFO] [1672660346.111618477] [Image_Subscriber]: Image Received
# [INFO] [1672660346.152834512] [Image_Subscriber]: Image Received
# [INFO] [1672660346.201225822] [Image_Subscriber]: Image Received
# [INFO] [1672660346.273043570] [Image_Subscriber]: Image Received
# [INFO] [1672660346.347300051] [Image_Subscriber]: Image Received
# [INFO] [1672660346.404462261] [Image_Subscriber]: Image Received
# [INFO] [1672660346.444945361] [Image_Subscriber]: Image Received
# [INFO] [1672660346.479638870] [Image_Subscriber]: Image Received
# [INFO] [1672660346.566068496] [Image_Subscriber]: Image Received
# [INFO] [1672660346.610126842] [Image_Subscriber]: Image Received
# [INFO] [1672660346.659103159] [Image_Subscriber]: Image Received
# [INFO] [1672660346.697689907] [Image_Subscriber]: Image Received
# [INFO] [1672660346.773470844] [Image_Subscriber]: Image Received
# [INFO] [1672660346.851795182] [Image_Subscriber]: Image Received
# [INFO] [1672660346.910138962] [Image_Subscriber]: Image Received
# [INFO] [1672660346.959922982] [Image_Subscriber]: Image Received
# [INFO] [1672660347.002541452] [Image_Subscriber]: Image Received
# [INFO] [1672660347.080097935] [Image_Subscriber]: Image Received
# [INFO] [1672660347.114852002] [Image_Subscriber]: Image Received
# [INFO] [1672660347.165088727] [Image_Subscriber]: Image Received
# [INFO] [1672660347.211129627] [Image_Subscriber]: Image Received
# [INFO] [1672660347.279175761] [Image_Subscriber]: Image Received
# [INFO] [1672660347.315741055] [Image_Subscriber]: Image Received
# [INFO] [1672660347.376123708] [Image_Subscriber]: Image Received
# [INFO] [1672660347.442380700] [Image_Subscriber]: Image Received
# [INFO] [1672660347.494725711] [Image_Subscriber]: Image Received
# [INFO] [1672660347.565747714] [Image_Subscriber]: Image Received
# [INFO] [1672660347.618052940] [Image_Subscriber]: Image Received
# [INFO] [1672660347.679970444] [Image_Subscriber]: Image Received
# [INFO] [1672660347.730108650] [Image_Subscriber]: Image Received
# [INFO] [1672660347.786059022] [Image_Subscriber]: Image Received
# [INFO] [1672660347.866594697] [Image_Subscriber]: Image Received
# [INFO] [1672660347.889463533] [Image_Subscriber]: Image Received
# [INFO] [1672660347.949979296] [Image_Subscriber]: Image Received
# [INFO] [1672660348.025224421] [Image_Subscriber]: Image Received
# [INFO] [1672660348.088914245] [Image_Subscriber]: Image Received
# [INFO] [1672660348.132273267] [Image_Subscriber]: Image Received
# [INFO] [1672660348.198228293] [Image_Subscriber]: Image Received
# [INFO] [1672660348.275989241] [Image_Subscriber]: Image Received
# [INFO] [1672660348.311449440] [Image_Subscriber]: Image Received
# [INFO] [1672660348.378571329] [Image_Subscriber]: Image Received
# [INFO] [1672660348.418165805] [Image_Subscriber]: Image Received
# [INFO] [1672660348.477155873] [Image_Subscriber]: Image Received
# [INFO] [1672660348.554625838] [Image_Subscriber]: Image Received
# [INFO] [1672660348.594617385] [Image_Subscriber]: Image Received
# [INFO] [1672660348.675812685] [Image_Subscriber]: Image Received
# [INFO] [1672660348.723015481] [Image_Subscriber]: Image Received
# [INFO] [1672660348.785921065] [Image_Subscriber]: Image Received
# [INFO] [1672660348.822080900] [Image_Subscriber]: Image Received
# [INFO] [1672660348.886794771] [Image_Subscriber]: Image Received
# [INFO] [1672660348.944766617] [Image_Subscriber]: Image Received
# [INFO] [1672660349.006341856] [Image_Subscriber]: Image Received
# [INFO] [1672660349.044700167] [Image_Subscriber]: Image Received
# [INFO] [1672660349.125346898] [Image_Subscriber]: Image Received
# [INFO] [1672660349.174114597] [Image_Subscriber]: Image Received
# [INFO] [1672660349.250620763] [Image_Subscriber]: Image Received
# [INFO] [1672660349.311661040] [Image_Subscriber]: Image Received
# [INFO] [1672660349.382089206] [Image_Subscriber]: Image Received
# [INFO] [1672660349.421977481] [Image_Subscriber]: Image Received
# [INFO] [1672660349.504857792] [Image_Subscriber]: Image Received
# [INFO] [1672660349.548855498] [Image_Subscriber]: Image Received
# [INFO] [1672660349.591344482] [Image_Subscriber]: Image Received
# [INFO] [1672660349.641832148] [Image_Subscriber]: Image Received
# [INFO] [1672660349.698824468] [Image_Subscriber]: Image Received
# [INFO] [1672660349.787636233] [Image_Subscriber]: Image Received
# [INFO] [1672660349.845855527] [Image_Subscriber]: Image Received
# [INFO] [1672660349.896213082] [Image_Subscriber]: Image Received
# [INFO] [1672660349.934719273] [Image_Subscriber]: Image Received
# [INFO] [1672660350.012317851] [Image_Subscriber]: Image Received
# [INFO] [1672660350.049301102] [Image_Subscriber]: Image Received
# [INFO] [1672660350.112908155] [Image_Subscriber]: Image Received
# [INFO] [1672660350.171490924] [Image_Subscriber]: Image Received
# [INFO] [1672660350.246347449] [Image_Subscriber]: Image Received
# [INFO] [1672660350.317374150] [Image_Subscriber]: Image Received
# [INFO] [1672660350.368239998] [Image_Subscriber]: Image Received
# [INFO] [1672660350.429786156] [Image_Subscriber]: Image Received
# [INFO] [1672660350.490402538] [Image_Subscriber]: Image Received
# [INFO] [1672660350.543716971] [Image_Subscriber]: Image Received
# [INFO] [1672660350.602366294] [Image_Subscriber]: Image Received
# [INFO] [1672660350.639627911] [Image_Subscriber]: Image Received
# [INFO] [1672660350.723651375] [Image_Subscriber]: Image Received
# [INFO] [1672660350.778427371] [Image_Subscriber]: Image Received
# [INFO] [1672660350.838674428] [Image_Subscriber]: Image Received
# [INFO] [1672660350.889549885] [Image_Subscriber]: Image Received
# [INFO] [1672660350.912868284] [Image_Subscriber]: Image Received
# [INFO] [1672660350.995928665] [Image_Subscriber]: Image Received
# [INFO] [1672660351.047191101] [Image_Subscriber]: Image Received
# [INFO] [1672660351.105281048] [Image_Subscriber]: Image Received
# [INFO] [1672660351.160616541] [Image_Subscriber]: Image Received
# [INFO] [1672660351.203449172] [Image_Subscriber]: Image Received
# [INFO] [1672660351.284790265] [Image_Subscriber]: Image Received
# [INFO] [1672660351.330423432] [Image_Subscriber]: Image Received
# [INFO] [1672660351.387543976] [Image_Subscriber]: Image Received
# [INFO] [1672660351.438483544] [Image_Subscriber]: Image Received
# [INFO] [1672660351.507220961] [Image_Subscriber]: Image Received
# [INFO] [1672660351.576811846] [Image_Subscriber]: Image Received
# [INFO] [1672660351.621879455] [Image_Subscriber]: Image Received
# [INFO] [1672660351.689180733] [Image_Subscriber]: Image Received
# [INFO] [1672660351.736693568] [Image_Subscriber]: Image Received
# [INFO] [1672660351.798615876] [Image_Subscriber]: Image Received
# [INFO] [1672660351.834361516] [Image_Subscriber]: Image Received
# [INFO] [1672660351.893715223] [Image_Subscriber]: Image Received
# [INFO] [1672660351.980756554] [Image_Subscriber]: Image Received
# [INFO] [1672660352.032011728] [Image_Subscriber]: Image Received
# [INFO] [1672660352.075885517] [Image_Subscriber]: Image Received
# [INFO] [1672660352.177370314] [Image_Subscriber]: Image Received
# [INFO] [1672660352.214855780] [Image_Subscriber]: Image Received
# [INFO] [1672660352.285722707] [Image_Subscriber]: Image Received
# [INFO] [1672660352.312400590] [Image_Subscriber]: Image Received
# [INFO] [1672660352.371429788] [Image_Subscriber]: Image Received
# [INFO] [1672660352.395749589] [Image_Subscriber]: Image Received
# [INFO] [1672660352.480153862] [Image_Subscriber]: Image Received
# [INFO] [1672660352.524679626] [Image_Subscriber]: Image Received
# [INFO] [1672660352.586083149] [Image_Subscriber]: Image Received
# [INFO] [1672660352.624139715] [Image_Subscriber]: Image Received
# [INFO] [1672660352.688917588] [Image_Subscriber]: Image Received
# [INFO] [1672660352.745937148] [Image_Subscriber]: Image Received
# [INFO] [1672660352.818925853] [Image_Subscriber]: Image Received
# [INFO] [1672660352.868967202] [Image_Subscriber]: Image Received
# [INFO] [1672660352.914211765] [Image_Subscriber]: Image Received
# [INFO] [1672660352.981739345] [Image_Subscriber]: Image Received
# [INFO] [1672660353.030066064] [Image_Subscriber]: Image Received
# [INFO] [1672660353.087781913] [Image_Subscriber]: Image Received
# [INFO] [1672660353.136447097] [Image_Subscriber]: Image Received
# [INFO] [1672660353.203705585] [Image_Subscriber]: Image Received
# [INFO] [1672660353.255803652] [Image_Subscriber]: Image Received
# [INFO] [1672660353.314042455] [Image_Subscriber]: Image Received
# [INFO] [1672660353.388764477] [Image_Subscriber]: Image Received
# [INFO] [1672660353.437716502] [Image_Subscriber]: Image Received
# [INFO] [1672660353.487910830] [Image_Subscriber]: Image Received
# [INFO] [1672660353.540743080] [Image_Subscriber]: Image Received
# [INFO] [1672660353.622084154] [Image_Subscriber]: Image Received
# [INFO] [1672660353.694313298] [Image_Subscriber]: Image Received
# [INFO] [1672660353.734242554] [Image_Subscriber]: Image Received
# [INFO] [1672660353.804478271] [Image_Subscriber]: Image Received
# [INFO] [1672660353.868842438] [Image_Subscriber]: Image Received
# [INFO] [1672660353.913438854] [Image_Subscriber]: Image Received
# [INFO] [1672660353.995613256] [Image_Subscriber]: Image Received
# [INFO] [1672660354.038573088] [Image_Subscriber]: Image Received
# [INFO] [1672660354.103533092] [Image_Subscriber]: Image Received
# [INFO] [1672660354.142742796] [Image_Subscriber]: Image Received
# [INFO] [1672660354.212516879] [Image_Subscriber]: Image Received
# [INFO] [1672660354.275041307] [Image_Subscriber]: Image Received
# [INFO] [1672660354.342703620] [Image_Subscriber]: Image Received
# [INFO] [1672660354.401390464] [Image_Subscriber]: Image Received
# [INFO] [1672660354.446910665] [Image_Subscriber]: Image Received
# [INFO] [1672660354.493611780] [Image_Subscriber]: Image Received
# [INFO] [1672660354.556884102] [Image_Subscriber]: Image Received
# [INFO] [1672660354.612774096] [Image_Subscriber]: Image Received
# [INFO] [1672660354.641870738] [Image_Subscriber]: Image Received
# [INFO] [1672660354.693821355] [Image_Subscriber]: Image Received
# [INFO] [1672660354.725664370] [Image_Subscriber]: Image Received
# [INFO] [1672660354.798091417] [Image_Subscriber]: Image Received
# [INFO] [1672660354.820178301] [Image_Subscriber]: Image Received
# [INFO] [1672660354.870373108] [Image_Subscriber]: Image Received
# [INFO] [1672660354.917338180] [Image_Subscriber]: Image Received
# [INFO] [1672660354.989670008] [Image_Subscriber]: Image Received
# [INFO] [1672660355.038886207] [Image_Subscriber]: Image Received
# [INFO] [1672660355.085202483] [Image_Subscriber]: Image Received
# [INFO] [1672660355.149025381] [Image_Subscriber]: Image Received
# [INFO] [1672660355.182271661] [Image_Subscriber]: Image Received
# [INFO] [1672660355.245102895] [Image_Subscriber]: Image Received
# [INFO] [1672660355.305564788] [Image_Subscriber]: Image Received
# [INFO] [1672660355.373601909] [Image_Subscriber]: Image Received
# [INFO] [1672660355.431795082] [Image_Subscriber]: Image Received
# [INFO] [1672660355.495008854] [Image_Subscriber]: Image Received
# [INFO] [1672660355.538197358] [Image_Subscriber]: Image Received
# [INFO] [1672660355.604399761] [Image_Subscriber]: Image Received
# [INFO] [1672660355.646689012] [Image_Subscriber]: Image Received
# [INFO] [1672660355.706528210] [Image_Subscriber]: Image Received
# [INFO] [1672660355.777266208] [Image_Subscriber]: Image Received
# [INFO] [1672660355.828098723] [Image_Subscriber]: Image Received
# [INFO] [1672660355.893483549] [Image_Subscriber]: Image Received
# [INFO] [1672660355.928200809] [Image_Subscriber]: Image Received
# [INFO] [1672660355.996205193] [Image_Subscriber]: Image Received
# [INFO] [1672660356.046997827] [Image_Subscriber]: Image Received
# [INFO] [1672660356.094634962] [Image_Subscriber]: Image Received
# [INFO] [1672660356.187359528] [Image_Subscriber]: Image Received
# [INFO] [1672660356.228371010] [Image_Subscriber]: Image Received
# [INFO] [1672660356.277870950] [Image_Subscriber]: Image Received
# [INFO] [1672660356.308463330] [Image_Subscriber]: Image Received
# [INFO] [1672660356.370613225] [Image_Subscriber]: Image Received
# [INFO] [1672660356.409877575] [Image_Subscriber]: Image Received
# [INFO] [1672660356.474593453] [Image_Subscriber]: Image Received
# [INFO] [1672660356.551076765] [Image_Subscriber]: Image Received
# [INFO] [1672660356.578733877] [Image_Subscriber]: Image Received
# [INFO] [1672660356.656683773] [Image_Subscriber]: Image Received
# [INFO] [1672660356.711324189] [Image_Subscriber]: Image Received
# [INFO] [1672660356.763939139] [Image_Subscriber]: Image Received
# [INFO] [1672660356.801154583] [Image_Subscriber]: Image Received
# [INFO] [1672660356.851638926] [Image_Subscriber]: Image Received
# [INFO] [1672660356.908240610] [Image_Subscriber]: Image Received
# [INFO] [1672660356.965013691] [Image_Subscriber]: Image Received
# [INFO] [1672660357.004411026] [Image_Subscriber]: Image Received
# [INFO] [1672660357.081615050] [Image_Subscriber]: Image Received
# [INFO] [1672660357.129934718] [Image_Subscriber]: Image Received
# [INFO] [1672660357.200700175] [Image_Subscriber]: Image Received
# [INFO] [1672660357.218936907] [Image_Subscriber]: Image Received
# [INFO] [1672660357.292585209] [Image_Subscriber]: Image Received
# [INFO] [1672660357.364628104] [Image_Subscriber]: Image Received
# [INFO] [1672660357.382930476] [Image_Subscriber]: Image Received
# [INFO] [1672660357.451016413] [Image_Subscriber]: Image Received
# [INFO] [1672660357.521944654] [Image_Subscriber]: Image Received
# [INFO] [1672660357.569878985] [Image_Subscriber]: Image Received
# [INFO] [1672660357.639686249] [Image_Subscriber]: Image Received
# [INFO] [1672660357.692953029] [Image_Subscriber]: Image Received
# [INFO] [1672660357.755504777] [Image_Subscriber]: Image Received
# [INFO] [1672660357.801719300] [Image_Subscriber]: Image Received
# [INFO] [1672660357.867966585] [Image_Subscriber]: Image Received
# [INFO] [1672660357.927260170] [Image_Subscriber]: Image Received
# [INFO] [1672660357.997356837] [Image_Subscriber]: Image Received
# [INFO] [1672660358.070104471] [Image_Subscriber]: Image Received
# [INFO] [1672660358.120135711] [Image_Subscriber]: Image Received
# [INFO] [1672660358.181722984] [Image_Subscriber]: Image Received
# [INFO] [1672660358.222890414] [Image_Subscriber]: Image Received
# [INFO] [1672660358.295851506] [Image_Subscriber]: Image Received
# [INFO] [1672660358.325908165] [Image_Subscriber]: Image Received
# [INFO] [1672660358.369095323] [Image_Subscriber]: Image Received
# [INFO] [1672660358.427768445] [Image_Subscriber]: Image Received
# [INFO] [1672660358.476188779] [Image_Subscriber]: Image Received
# [INFO] [1672660358.532483042] [Image_Subscriber]: Image Received
# [INFO] [1672660358.601472226] [Image_Subscriber]: Image Received
# [INFO] [1672660358.673789837] [Image_Subscriber]: Image Received
# [INFO] [1672660358.721538284] [Image_Subscriber]: Image Received
# [INFO] [1672660358.785258357] [Image_Subscriber]: Image Received
# [INFO] [1672660358.838443026] [Image_Subscriber]: Image Received
# [INFO] [1672660358.899608531] [Image_Subscriber]: Image Received
# [INFO] [1672660358.935982122] [Image_Subscriber]: Image Received
# [INFO] [1672660359.004185118] [Image_Subscriber]: Image Received
# [INFO] [1672660359.078536439] [Image_Subscriber]: Image Received
# [INFO] [1672660359.125401790] [Image_Subscriber]: Image Received
# [INFO] [1672660359.188193430] [Image_Subscriber]: Image Received
# [INFO] [1672660359.241103554] [Image_Subscriber]: Image Received
# [INFO] [1672660359.319355662] [Image_Subscriber]: Image Received
# [INFO] [1672660359.366368299] [Image_Subscriber]: Image Received
# [INFO] [1672660359.405877642] [Image_Subscriber]: Image Received
# [INFO] [1672660359.470594516] [Image_Subscriber]: Image Received
# [INFO] [1672660359.543250020] [Image_Subscriber]: Image Received
# [INFO] [1672660359.591204234] [Image_Subscriber]: Image Received
# [INFO] [1672660359.644423504] [Image_Subscriber]: Image Received
# [INFO] [1672660359.698072574] [Image_Subscriber]: Image Received
# [INFO] [1672660359.725733198] [Image_Subscriber]: Image Received
# [INFO] [1672660359.817818190] [Image_Subscriber]: Image Received
# [INFO] [1672660359.878729997] [Image_Subscriber]: Image Received
# [INFO] [1672660359.923429773] [Image_Subscriber]: Image Received
# [INFO] [1672660359.988363324] [Image_Subscriber]: Image Received
# [INFO] [1672660360.072279383] [Image_Subscriber]: Image Received
# [INFO] [1672660360.103525285] [Image_Subscriber]: Image Received
# [INFO] [1672660360.156789660] [Image_Subscriber]: Image Received
# [INFO] [1672660360.216243011] [Image_Subscriber]: Image Received
# [INFO] [1672660360.282092754] [Image_Subscriber]: Image Received
# [INFO] [1672660360.318073260] [Image_Subscriber]: Image Received
# [INFO] [1672660360.366305012] [Image_Subscriber]: Image Received
# [INFO] [1672660360.429140175] [Image_Subscriber]: Image Received
# [INFO] [1672660360.492628153] [Image_Subscriber]: Image Received
# [INFO] [1672660360.543349996] [Image_Subscriber]: Image Received
# [INFO] [1672660360.601320965] [Image_Subscriber]: Image Received
# [INFO] [1672660360.694476108] [Image_Subscriber]: Image Received
# [INFO] [1672660360.732888842] [Image_Subscriber]: Image Received
# [INFO] [1672660360.800467421] [Image_Subscriber]: Image Received
# [INFO] [1672660360.866642963] [Image_Subscriber]: Image Received
# [INFO] [1672660360.905003152] [Image_Subscriber]: Image Received
# [INFO] [1672660360.955254886] [Image_Subscriber]: Image Received
# [INFO] [1672660361.048683643] [Image_Subscriber]: Image Received
# [INFO] [1672660361.102166076] [Image_Subscriber]: Image Received
# [INFO] [1672660361.141074781] [Image_Subscriber]: Image Received
# [INFO] [1672660361.194868370] [Image_Subscriber]: Image Received
# [INFO] [1672660361.278311302] [Image_Subscriber]: Image Received
# [INFO] [1672660361.305640645] [Image_Subscriber]: Image Received
# [INFO] [1672660361.372850574] [Image_Subscriber]: Image Received
# [INFO] [1672660361.437364104] [Image_Subscriber]: Image Received
# [INFO] [1672660361.488487479] [Image_Subscriber]: Image Received
# [INFO] [1672660361.512779676] [Image_Subscriber]: Image Received
# [INFO] [1672660361.601450618] [Image_Subscriber]: Image Received
# [INFO] [1672660361.638184674] [Image_Subscriber]: Image Received
# [INFO] [1672660361.690348537] [Image_Subscriber]: Image Received
# [INFO] [1672660361.748008424] [Image_Subscriber]: Image Received
# [INFO] [1672660361.805061142] [Image_Subscriber]: Image Received
# [INFO] [1672660361.866533161] [Image_Subscriber]: Image Received
# [INFO] [1672660361.919050904] [Image_Subscriber]: Image Received
# [INFO] [1672660361.960539558] [Image_Subscriber]: Image Received
# [INFO] [1672660362.012173685] [Image_Subscriber]: Image Received
# [INFO] [1672660362.061966231] [Image_Subscriber]: Image Received
# [INFO] [1672660362.127730957] [Image_Subscriber]: Image Received
# [INFO] [1672660362.190891748] [Image_Subscriber]: Image Received
# [INFO] [1672660362.240873260] [Image_Subscriber]: Image Received
# [INFO] [1672660362.279582884] [Image_Subscriber]: Image Received
# [INFO] [1672660362.345873765] [Image_Subscriber]: Image Received
# [INFO] [1672660362.388559243] [Image_Subscriber]: Image Received
# [INFO] [1672660362.438940603] [Image_Subscriber]: Image Received
# [INFO] [1672660362.485882503] [Image_Subscriber]: Image Received
# [INFO] [1672660362.536838163] [Image_Subscriber]: Image Received
# [INFO] [1672660362.582845318] [Image_Subscriber]: Image Received
# [INFO] [1672660362.677651946] [Image_Subscriber]: Image Received
# [INFO] [1672660362.730468066] [Image_Subscriber]: Image Received
# [INFO] [1672660362.784291508] [Image_Subscriber]: Image Received
# [INFO] [1672660362.834443715] [Image_Subscriber]: Image Received
# [INFO] [1672660362.891307082] [Image_Subscriber]: Image Received
# [INFO] [1672660362.971102090] [Image_Subscriber]: Image Received
# [INFO] [1672660363.006085649] [Image_Subscriber]: Image Received
# [INFO] [1672660363.076607035] [Image_Subscriber]: Image Received
# [INFO] [1672660363.131644633] [Image_Subscriber]: Image Received
# [INFO] [1672660363.189100767] [Image_Subscriber]: Image Received
# [INFO] [1672660363.250290121] [Image_Subscriber]: Image Received
# [INFO] [1672660363.332079343] [Image_Subscriber]: Image Received
# [INFO] [1672660363.391305159] [Image_Subscriber]: Image Received
# [INFO] [1672660363.440373113] [Image_Subscriber]: Image Received
# [INFO] [1672660363.493565972] [Image_Subscriber]: Image Received
# [INFO] [1672660363.536398556] [Image_Subscriber]: Image Received
# [INFO] [1672660363.623186252] [Image_Subscriber]: Image Received
# [INFO] [1672660363.679812722] [Image_Subscriber]: Image Received
# [INFO] [1672660363.708505341] [Image_Subscriber]: Image Received
# [INFO] [1672660363.789716208] [Image_Subscriber]: Image Received
# [INFO] [1672660363.831701887] [Image_Subscriber]: Image Received
# [INFO] [1672660363.885942590] [Image_Subscriber]: Image Received
# [INFO] [1672660363.978962010] [Image_Subscriber]: Image Received
# [INFO] [1672660364.047089128] [Image_Subscriber]: Image Received
# [INFO] [1672660364.093530572] [Image_Subscriber]: Image Received
# [INFO] [1672660364.169265916] [Image_Subscriber]: Image Received
# [INFO] [1672660364.192907730] [Image_Subscriber]: Image Received
# [INFO] [1672660364.240733188] [Image_Subscriber]: Image Received
# [INFO] [1672660364.300293352] [Image_Subscriber]: Image Received
# [INFO] [1672660364.342127902] [Image_Subscriber]: Image Received
# [INFO] [1672660364.395503070] [Image_Subscriber]: Image Received
# [INFO] [1672660364.472252340] [Image_Subscriber]: Image Received
# [INFO] [1672660364.519580269] [Image_Subscriber]: Image Received
# [INFO] [1672660364.569574094] [Image_Subscriber]: Image Received
# [INFO] [1672660364.618146198] [Image_Subscriber]: Image Received
# [INFO] [1672660364.663681515] [Image_Subscriber]: Image Received
# [INFO] [1672660364.731766904] [Image_Subscriber]: Image Received
# [INFO] [1672660364.804351253] [Image_Subscriber]: Image Received
# [INFO] [1672660364.862970288] [Image_Subscriber]: Image Received
# [INFO] [1672660364.902956616] [Image_Subscriber]: Image Received
# [INFO] [1672660364.972498400] [Image_Subscriber]: Image Received
# [INFO] [1672660365.040220274] [Image_Subscriber]: Image Received
# [INFO] [1672660365.081845621] [Image_Subscriber]: Image Received
# [INFO] [1672660365.152329342] [Image_Subscriber]: Image Received
# [INFO] [1672660365.199120740] [Image_Subscriber]: Image Received
# [INFO] [1672660365.255776762] [Image_Subscriber]: Image Received
# [INFO] [1672660365.297818115] [Image_Subscriber]: Image Received
# [INFO] [1672660365.376947867] [Image_Subscriber]: Image Received
# [INFO] [1672660365.428185916] [Image_Subscriber]: Image Received
# [INFO] [1672660365.494312622] [Image_Subscriber]: Image Received
# [INFO] [1672660365.548253326] [Image_Subscriber]: Image Received
# [INFO] [1672660365.602073662] [Image_Subscriber]: Image Received
# [INFO] [1672660365.666212402] [Image_Subscriber]: Image Received
# [INFO] [1672660365.707441309] [Image_Subscriber]: Image Received
# [INFO] [1672660365.777563001] [Image_Subscriber]: Image Received
# [INFO] [1672660365.822828070] [Image_Subscriber]: Image Received
# [INFO] [1672660365.873485164] [Image_Subscriber]: Image Received
# [INFO] [1672660365.923396906] [Image_Subscriber]: Image Received
# [INFO] [1672660365.974947614] [Image_Subscriber]: Image Received
# [INFO] [1672660366.029031368] [Image_Subscriber]: Image Received
# [INFO] [1672660366.082071355] [Image_Subscriber]: Image Received
# [INFO] [1672660366.164367619] [Image_Subscriber]: Image Received
# [INFO] [1672660366.183007914] [Image_Subscriber]: Image Received
# [INFO] [1672660366.265407287] [Image_Subscriber]: Image Received
# [INFO] [1672660366.305147309] [Image_Subscriber]: Image Received
# [INFO] [1672660366.380370604] [Image_Subscriber]: Image Received
# [INFO] [1672660366.419089963] [Image_Subscriber]: Image Received
# [INFO] [1672660366.472854896] [Image_Subscriber]: Image Received
# [INFO] [1672660366.507265849] [Image_Subscriber]: Image Received
# [INFO] [1672660366.571976743] [Image_Subscriber]: Image Received
# [INFO] [1672660366.623250052] [Image_Subscriber]: Image Received
# [INFO] [1672660366.686104870] [Image_Subscriber]: Image Received
# [INFO] [1672660366.729176108] [Image_Subscriber]: Image Received
# [INFO] [1672660366.784410438] [Image_Subscriber]: Image Received
# [INFO] [1672660366.840237604] [Image_Subscriber]: Image Received
# [INFO] [1672660366.873300571] [Image_Subscriber]: Image Received
# [INFO] [1672660366.921459501] [Image_Subscriber]: Image Received
# [INFO] [1672660367.002663921] [Image_Subscriber]: Image Received
# [INFO] [1672660367.041959803] [Image_Subscriber]: Image Received
# [INFO] [1672660367.124695757] [Image_Subscriber]: Image Received
# [INFO] [1672660367.186207637] [Image_Subscriber]: Image Received
# [INFO] [1672660367.237898268] [Image_Subscriber]: Image Received
# [INFO] [1672660367.275993894] [Image_Subscriber]: Image Received
# [INFO] [1672660367.307872330] [Image_Subscriber]: Image Received
# [INFO] [1672660367.370662350] [Image_Subscriber]: Image Received
# [INFO] [1672660367.411601685] [Image_Subscriber]: Image Received
# [INFO] [1672660367.492657231] [Image_Subscriber]: Image Received
# [INFO] [1672660367.536331232] [Image_Subscriber]: Image Received
# [INFO] [1672660367.580504603] [Image_Subscriber]: Image Received
# [INFO] [1672660367.608712434] [Image_Subscriber]: Image Received
# [INFO] [1672660367.692081320] [Image_Subscriber]: Image Received
# [INFO] [1672660367.756994967] [Image_Subscriber]: Image Received
# [INFO] [1672660367.805495344] [Image_Subscriber]: Image Received
# [INFO] [1672660367.867763320] [Image_Subscriber]: Image Received
# [INFO] [1672660367.909515041] [Image_Subscriber]: Image Received
# [INFO] [1672660367.960089261] [Image_Subscriber]: Image Received
# [INFO] [1672660368.013349416] [Image_Subscriber]: Image Received
# [INFO] [1672660368.074381177] [Image_Subscriber]: Image Received
# [INFO] [1672660368.145546059] [Image_Subscriber]: Image Received
# [INFO] [1672660368.200102672] [Image_Subscriber]: Image Received
# [INFO] [1672660368.244145863] [Image_Subscriber]: Image Received
# [INFO] [1672660368.303397937] [Image_Subscriber]: Image Received
# [INFO] [1672660368.355224698] [Image_Subscriber]: Image Received
# [INFO] [1672660368.412445308] [Image_Subscriber]: Image Received
# [INFO] [1672660368.480122121] [Image_Subscriber]: Image Received
# [INFO] [1672660368.522088345] [Image_Subscriber]: Image Received
# [INFO] [1672660368.561477145] [Image_Subscriber]: Image Received
# [INFO] [1672660368.617595320] [Image_Subscriber]: Image Received
# [INFO] [1672660368.658882689] [Image_Subscriber]: Image Received
# [INFO] [1672660368.729176239] [Image_Subscriber]: Image Received
# [INFO] [1672660368.776800779] [Image_Subscriber]: Image Received
# [INFO] [1672660368.827125384] [Image_Subscriber]: Image Received
# [INFO] [1672660368.895728499] [Image_Subscriber]: Image Received
# [INFO] [1672660368.938250198] [Image_Subscriber]: Image Received
# [INFO] [1672660369.006484715] [Image_Subscriber]: Image Received
# [INFO] [1672660369.054152072] [Image_Subscriber]: Image Received
# [INFO] [1672660369.111297962] [Image_Subscriber]: Image Received
# [INFO] [1672660369.203180984] [Image_Subscriber]: Image Received
# [INFO] [1672660369.238391470] [Image_Subscriber]: Image Received
# [INFO] [1672660369.307176436] [Image_Subscriber]: Image Received
# [INFO] [1672660369.349008564] [Image_Subscriber]: Image Received
# [INFO] [1672660369.409977382] [Image_Subscriber]: Image Received
# [INFO] [1672660369.457905944] [Image_Subscriber]: Image Received
# [INFO] [1672660369.494359804] [Image_Subscriber]: Image Received
# [INFO] [1672660369.525806451] [Image_Subscriber]: Image Received
# [INFO] [1672660369.615076544] [Image_Subscriber]: Image Received
# [INFO] [1672660369.694244824] [Image_Subscriber]: Image Received
# [INFO] [1672660369.726063676] [Image_Subscriber]: Image Received
# [INFO] [1672660369.805633769] [Image_Subscriber]: Image Received
# [INFO] [1672660369.877044122] [Image_Subscriber]: Image Received
# [INFO] [1672660369.916485390] [Image_Subscriber]: Image Received
# [INFO] [1672660369.970997867] [Image_Subscriber]: Image Received
# [INFO] [1672660370.019944889] [Image_Subscriber]: Image Received
# [INFO] [1672660370.068634446] [Image_Subscriber]: Image Received
# [INFO] [1672660370.122111556] [Image_Subscriber]: Image Received
# [INFO] [1672660370.183412970] [Image_Subscriber]: Image Received
# [INFO] [1672660370.236824346] [Image_Subscriber]: Image Received
# [INFO] [1672660370.279058865] [Image_Subscriber]: Image Received
# [INFO] [1672660370.378303794] [Image_Subscriber]: Image Received
# [INFO] [1672660370.434742646] [Image_Subscriber]: Image Received
# [INFO] [1672660370.497761435] [Image_Subscriber]: Image Received
# [INFO] [1672660370.543314517] [Image_Subscriber]: Image Received
# [INFO] [1672660370.596866507] [Image_Subscriber]: Image Received
# [INFO] [1672660370.636685427] [Image_Subscriber]: Image Received
# [INFO] [1672660370.684001297] [Image_Subscriber]: Image Received
# [INFO] [1672660370.773259685] [Image_Subscriber]: Image Received
# [INFO] [1672660370.800296501] [Image_Subscriber]: Image Received
# [INFO] [1672660370.874559885] [Image_Subscriber]: Image Received
# [INFO] [1672660370.925172624] [Image_Subscriber]: Image Received
# [INFO] [1672660370.951773443] [Image_Subscriber]: Image Received
# [INFO] [1672660371.018891154] [Image_Subscriber]: Image Received
# [INFO] [1672660371.079316746] [Image_Subscriber]: Image Received
# [INFO] [1672660371.139271603] [Image_Subscriber]: Image Received
# [INFO] [1672660371.190513064] [Image_Subscriber]: Image Received
# [INFO] [1672660371.274624611] [Image_Subscriber]: Image Received
# [INFO] [1672660371.306963034] [Image_Subscriber]: Image Received
# [INFO] [1672660371.365482750] [Image_Subscriber]: Image Received
# [INFO] [1672660371.429889761] [Image_Subscriber]: Image Received
# [INFO] [1672660371.460722071] [Image_Subscriber]: Image Received
# [INFO] [1672660371.525394906] [Image_Subscriber]: Image Received
# [INFO] [1672660371.562970573] [Image_Subscriber]: Image Received
# [INFO] [1672660371.619625840] [Image_Subscriber]: Image Received
# [INFO] [1672660371.685949820] [Image_Subscriber]: Image Received
# [INFO] [1672660371.742190840] [Image_Subscriber]: Image Received
# [INFO] [1672660371.792962575] [Image_Subscriber]: Image Received
# [INFO] [1672660371.846715950] [Image_Subscriber]: Image Received
# [INFO] [1672660371.901246652] [Image_Subscriber]: Image Received
# [INFO] [1672660371.954727704] [Image_Subscriber]: Image Received
# [INFO] [1672660372.011755356] [Image_Subscriber]: Image Received
# [INFO] [1672660372.081671808] [Image_Subscriber]: Image Received
# [INFO] [1672660372.144657175] [Image_Subscriber]: Image Received
# [INFO] [1672660372.192539044] [Image_Subscriber]: Image Received
# [INFO] [1672660372.291986476] [Image_Subscriber]: Image Received
# [INFO] [1672660372.355951200] [Image_Subscriber]: Image Received
# [INFO] [1672660372.403113293] [Image_Subscriber]: Image Received
# [INFO] [1672660372.478240605] [Image_Subscriber]: Image Received
# [INFO] [1672660372.540491846] [Image_Subscriber]: Image Received
# [INFO] [1672660372.580129070] [Image_Subscriber]: Image Received
# [INFO] [1672660372.655631237] [Image_Subscriber]: Image Received
# [INFO] [1672660372.683585701] [Image_Subscriber]: Image Received
# [INFO] [1672660372.788874834] [Image_Subscriber]: Image Received
# [INFO] [1672660372.811952283] [Image_Subscriber]: Image Received
# [INFO] [1672660372.862878782] [Image_Subscriber]: Image Received
# [INFO] [1672660372.934267214] [Image_Subscriber]: Image Received
# [INFO] [1672660373.001206813] [Image_Subscriber]: Image Received
# [INFO] [1672660373.062023915] [Image_Subscriber]: Image Received
# [INFO] [1672660373.119884632] [Image_Subscriber]: Image Received
# [INFO] [1672660373.186668738] [Image_Subscriber]: Image Received
# [INFO] [1672660373.255211854] [Image_Subscriber]: Image Received
# [INFO] [1672660373.314270615] [Image_Subscriber]: Image Received
# [INFO] [1672660373.377134103] [Image_Subscriber]: Image Received
# [INFO] [1672660373.440023969] [Image_Subscriber]: Image Received
# [INFO] [1672660373.495093864] [Image_Subscriber]: Image Received
# [INFO] [1672660373.571727558] [Image_Subscriber]: Image Received
# [INFO] [1672660373.642576290] [Image_Subscriber]: Image Received
# [INFO] [1672660373.704589519] [Image_Subscriber]: Image Received
# [INFO] [1672660373.743630127] [Image_Subscriber]: Image Received
# [INFO] [1672660373.794008054] [Image_Subscriber]: Image Received
# [INFO] [1672660373.841872466] [Image_Subscriber]: Image Received
# [INFO] [1672660373.906872751] [Image_Subscriber]: Image Received
# [INFO] [1672660373.988269921] [Image_Subscriber]: Image Received
# [INFO] [1672660374.044377356] [Image_Subscriber]: Image Received
# [INFO] [1672660374.109043482] [Image_Subscriber]: Image Received
# [INFO] [1672660374.132915624] [Image_Subscriber]: Stopping the stream ...

# %%
quit()
