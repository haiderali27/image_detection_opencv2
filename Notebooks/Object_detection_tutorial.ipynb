# %% [markdown]
# #   ROS2 | Exercise 4 - Computer Vision
#
# ##  Task 3 - Object Detection
#
# ### Pre-requisites
# Before you begin this Notebook you have to complete the following tasks explained in the handout
# - [x] Setting up the gazebo simulation as a ROS package
# - [x] Setting up Conda environment to run this jupyter notebook
#
# ### Introduction
# Object detection and its importance in robotics. Opencv Intro. Some images
#
# There are 3 parts in this Notebook which covers the following
#    - 3.1 : Basic Image processing and Opencv contour detection
#    - 3.2 : Object detection and Tracking with Video
#    - 3.3 : Object detection and Tracking with ROS2

# %% [markdown]
# ***
# ### 3.1 Basic Image processing with OpenCV
#
# ### 3.1.1
# Familiarize yourself with the basic functionalities available in openCV for basic image reading and visualization with this reference [link](https://docs.opencv.org/4.x/db/deb/tutorial_display_image.html). It has both C++ & Python code. We are following python in this notebook. Execute the following code that reads an image file and displays it in an opencv window.

# %%
import imutils
import cv2
import numpy as np

frame = cv2.imread('image.png')
cv2.imshow("Tracking",frame)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.2
#
# It is important to  pre-process raw input images in computer vision tasks such as object detection and tracking. OpenCV imgproc module contains several functionalities which are often used in image processing.
#
# Convertion between color spaces is necessary to generate image masks. Execute and observe the following code where you convert an image from RGB to HSV color space. The code generates a mask of the green color object.
#
# **Your task**
#
# - [ ] Change HSV values in order to generate masks of other objects.
#
# **References**
# - [Concept of HSL and HSV Color spaces](https://en.wikipedia.org/wiki/HSL_and_HSV)
# - [Opencv basic Image processing functionalities](https://docs.opencv.org/4.x/d7/da8/tutorial_table_of_content_imgproc.html)
# - [OpenCV RGB-HSV color converstions documentation](https://docs.opencv.org/3.4.6/de/d25/imgproc_color_conversions.html#color_convert_rgb_hsv)

# %%
# lower and upper boundaries for HSV thresholds
#Lower = (29, 86, 64)
#Upper = (64, 255, 255)

Lower = (29, 86, 64)
Upper = (180, 255, 255)
kernel = np.ones((11,11),np.float32)/25

    

def prep(frame):
    frame = imutils.resize(frame, width=600)
    kernel = np.ones((11, 11), np.uint8)

    ## Todo 3.1.3 gaussian blur
    # blurred =
    blurred = cv2.GaussianBlur(frame, (11,11), 0)
    
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv,Lower,Upper)

    ## Todo 3.1.3 gaussian blur
    mask = cv2.erode(mask, kernel, iterations=0)

    mask = cv2.dilate(mask, kernel, iterations=0)
    return mask, frame

mask,frame = prep(frame)

cv2.imshow("Image",frame)
cv2.imshow("Masked Image",mask)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.3
#
# The above implementation provides a satisfactory result. However, when dealing with noisy images it is important to perform morphological transformations such as smoothing, erotion and dialation to get better results.
#
# **Your task**
#
# Read the following documentations and implement the following transformations inside the prep_frame() function above.
#
#
# - [ ] Apply Gaussian blur with a kernel size of 11x11
# - [ ] Apply erosion
# - [ ] Apply dialation
#
# **References**
#
# - [Smoothing Images with OpenCV](https://docs.opencv.org/4.5.2/d4/d13/tutorial_py_filtering.html)
# - [Perform Erosion and Dialation on the image mask using OpenCV](https://docs.opencv.org/3.4/db/df6/tutorial_erosion_dilatation.html)

# %% [markdown]
# ### 3.1.4
#
# Finding contours in an image is useful in object detection and tracking. The code snippet below extracts contours from the image file and draws a circle with its center as the same center of detected contour. Execute the code below and observe the results.
#
# **References**
# - [ Detecting contours with OpenCV](https://docs.opencv.org/4.5.0/d4/d73/tutorial_py_contours_begin.html)

# %%
### Find contours and display
def find_cnts(mask):
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    return cnts
def detect_conts(frame):
    mask,frame = prep(frame)
    cnts = find_cnts(mask)
    c = max(cnts, key=cv2.contourArea)
    ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?

    # Find center of contour using moments in opencvq
    M = cv2.moments(c)
    center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

    #circle
    frame1 = frame
    cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
    cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
    #cv2.imshow("Circle", frame1)


    ## ToDo 3.1.5 
    #  1. Bounding rectancgle

    # Loop over the contours
    for c in cnts:
        # Get the bounding rectangle of the contour
        x, y, w, h = cv2.boundingRect(c)
        # Draw the bounding rectangle on the image
        cv2.rectangle(frame1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Get the rotated bounding rectangle of the contour
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        # Draw the rotated bounding rectangle on the image

        cv2.drawContours(frame1, [box], 0, (0, 0, 255), 2)

        hull = cv2.convexHull(c)
        # Draw the convex hull on the image
        cv2.drawContours(frame1, [hull], 0, (255, 0, 0), 2)


    # Show the image with the bounding rectangles
    cv2.imshow("Bounding Rectangles", frame1)


    #  2. Convex Hull
    return frame1

def draw_conts(frame):
    mask,frame = prep(frame)
    cnts = find_cnts(mask)
    c = max(cnts, key=cv2.contourArea)
    ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?

    # Find center of contour using moments in opencvq
    M = cv2.moments(c)
    center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

    #circle
    frame1 = frame
    cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
    cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
    #cv2.imshow("Circle", frame1)


    ## ToDo 3.1.5 
    #  1. Bounding rectancgle

    # Loop over the contours
    for c in cnts:
        # Get the bounding rectangle of the contour
        x, y, w, h = cv2.boundingRect(c)
        # Draw the bounding rectangle on the image
        cv2.rectangle(frame1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Get the rotated bounding rectangle of the contour
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        # Draw the rotated bounding rectangle on the image

        cv2.drawContours(frame1, [box], 0, (0, 0, 255), 2)

        hull = cv2.convexHull(c)
        # Draw the convex hull on the image
        cv2.drawContours(frame1, [hull], 0, (255, 0, 0), 2)


    # Show the image with the bounding rectangles
    cv2.imshow("Bounding Rectangles", frame1)


    #  2. Convex Hull


    cv2.waitKey(0) & 0xFF
    cv2.destroyAllWindows()

frame = cv2.imread('image.png')
draw_conts(frame)
# Out:
# /tmp/ipykernel_10736/763091239.py:83: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)

# %% [markdown]
# ***
# ### 3.2 Object detection and Tracking with Video
#
# ### 3.2.1
#
# Execute and observe the below code snippet which reads frames from a given video file at a pre-defined frame rate.
#
# **Your task**
# - [ ] Implement pre-processing and find contour of the moving blob on by modifiying the same code below
# - [ ] Implement a suitable labelling mode (Enclosed Circle / bounding Box or convex hull) and display the resulted tracking on a seperated window
#
# **Tip** : Use the same functions from 3.1. Avoid creating duplicate functions and unnecessarily lenghty code

# %% [markdown]
# ### 3.1.5
# The above implementation only uses a minimum enclosing circle for labelling the detected image. There are more labelling options such as bounding boxes and convex hull which may come handy in various computer vision tasks.
#
# **Your task**
#
# - [ ] Implement a bounding rectangle and rotated rectangle on the detected contours by modifying the code in 3.1.4
# - [ ] Implement a convex hull on the detected contours by modifying the code in 3.1.4
#
# **References**
# - [Contour features in OpenCV](https://docs.opencv.org/4.x/dd/d49/tutorial_py_contour_features.html)
# - [Creating Bounding boxes and circles for contours](https://docs.opencv.org/4.x/da/d0c/tutorial_bounding_rects_circles.html)
# -[Convex Hull](https://docs.opencv.org/4.x/d7/d1d/tutorial_hull.html)

# %%
from imutils.video import VideoStream
import time

vs = cv2.VideoCapture("test_video.avi")
time.sleep(2.0)

frame_rate = 30
prev = 0

while True :
    time_elapsed = time.time() - prev
    
   
    
    if time_elapsed > 1./frame_rate:
        frame = vs.read()
        frame = frame[1]
        if frame is None:
            break
        frame = detect_conts(frame)
        cv2.imshow("Frame", frame)
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            break
        prev = time.time()
            
cv2.destroyAllWindows()
# Out:
# /tmp/ipykernel_10736/763091239.py:36: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)

# %% [markdown]
# ---
#
# ###  3.3 Object detection and Tracking with ROS2
#
# ### 3.3.1
#
# In applications concerning robotic perception, so often visual data are obtained via camera sensors interfaced with ros. In this section you are provided with a ros-ignition simulation package which publish camera sensor data. The code snippet below subscribes to the camera sensor data and stream on to an OpenCV window.
#
# Assuming you have successfully build the package on your system using the instructions from handout, Open a New shell in you terminal and launch the simulation.
#
# ```
# $ source /opt/ros/foxy/setup.bash
# $ cd ~/ws
# $ source install/setup.bash
# $ ros2 launch walking_actor cam_world.launch.py
# ```
#
# While the simulation is running in background , run the code snippet below and observe the result
#
# - To close the cv2 window , select the window and press 'q'
# - To stop the execution of code snippet, double press on 'i' in keyboard or interrupt the kernel from menu
#
#
# **Your task**
#
# - [ ] Modify the python code to track the walking actor. You can use any feature of the actor to track.
# - [ ] Display the tracking in a seperate cv2 window
#
#
# **References**
# - [ROS2 python subscriber/publisher](https://docs.ros.org/en/foxy/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Publisher-And-Subscriber.html)
# - [rclpy API Documentation](https://docs.ros2.org/foxy/api/rclpy/api/execution_and_callbacks.html#module-rclpy.executors)

# %%
import sys
import rclpy
import imutils

from rclpy.node import Node
from cv_bridge import CvBridge
import numpy as np
import cv2
from sensor_msgs.msg import Image, CameraInfo
#print(sys.path)


# lower and upper boundaries for HSV thresholds
#Lower = (29, 86, 64)
#Upper = (64, 255, 255)

Lower = (29, 86, 64)
Upper = (255, 255, 255)
kernel = np.ones((11,11),np.float32)/25

    

def prep(frame):
    frame = imutils.resize(frame, width=600)
    kernel = np.ones((11, 11), np.uint8)

    ## Todo 3.1.3 gaussian blur
    # blurred =
    blurred = cv2.GaussianBlur(frame, (11,11), 0)
    
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv,Lower,Upper)

    ## Todo 3.1.3 gaussian blur
    mask = cv2.erode(mask, kernel, iterations=0)

    mask = cv2.dilate(mask, kernel, iterations=0)
    return mask, frame


### Find contours and display
def find_cnts(mask):
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    return cnts
def detect_conts(frame):
    mask,frame = prep(frame)
    cnts = find_cnts(mask)
    c = max(cnts, key=cv2.contourArea)
    ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?

    # Find center of contour using moments in opencvq
    M = cv2.moments(c)
    center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

    #circle
    frame1 = frame
    cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
    cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
    #cv2.imshow("Circle", frame1)


    ## ToDo 3.1.5 
    #  1. Bounding rectancgle

    # Loop over the contours
    for c in cnts:
        # Get the bounding rectangle of the contour
        x, y, w, h = cv2.boundingRect(c)
        # Draw the bounding rectangle on the image
        cv2.rectangle(frame1, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Get the rotated bounding rectangle of the contour
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        # Draw the rotated bounding rectangle on the image

        cv2.drawContours(frame1, [box], 0, (0, 0, 255), 2)

        hull = cv2.convexHull(c)
        # Draw the convex hull on the image
        cv2.drawContours(frame1, [hull], 0, (255, 0, 0), 2)


    # Show the image with the bounding rectangles
    #cv2.imshow("Bounding Rectangles", frame1)


    #  2. Convex Hull
    return frame1

bridge = CvBridge()

class Get_Images(Node):

    def __init__(self):
        # Initialize the node
        super().__init__('Image_Subscriber')
        # Initialize the subscriber
        self.subscription_ = self.create_subscription( Image,'/camera', self.listener_callback,10)
        self.subscription_  # prevent unused variable warning
        timer_period = 0.1  # seconds
        self.timer = self.create_timer(timer_period, self.timer_callback)
        self.K = True

    def listener_callback(self, msg):
        height = msg.height
        width = msg.width
        channel = msg.step//msg.width
        #frame = np.reshape(msg.data, (height, width, channel))
        self.frame =  bridge.imgmsg_to_cv2(msg, desired_encoding='bgr8')
        self.get_logger().info("Image Received")
        return self.frame
    
    def timer_callback(self):
        if self.K == True:
            #cv2.imshow("Tracking",self.frame)
            cv2.imshow("Tracking",detect_conts(self.frame))
            key = cv2.waitKey(1) & 0xFF
            if key == ord("q"):
                self.get_logger().info('Closing stream window..')
                self.K = False
                cv2.destroyAllWindows()
        
                
    def stop_stream(self):
        self.get_logger().info('Stopping the stream ...')
        

try:
    
    rclpy.init(args=None)
    image_subscriber = Get_Images()
    rclpy.spin(image_subscriber)

except KeyboardInterrupt:
    # executes on keyboard kernal interrupt with double pressing button "i"
    image_subscriber.stop_stream()
    image_subscriber.destroy_node()
    rclpy.shutdown()
# Out:
# [INFO] [1673361507.115088323] [Image_Subscriber]: Image Received
# /tmp/ipykernel_10736/2085606676.py:76: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box)
# [INFO] [1673361507.199495193] [Image_Subscriber]: Image Received
# [INFO] [1673361507.274242606] [Image_Subscriber]: Image Received
# [INFO] [1673361507.339719564] [Image_Subscriber]: Image Received
# [INFO] [1673361507.401411460] [Image_Subscriber]: Image Received
# [INFO] [1673361507.449105014] [Image_Subscriber]: Image Received
# [INFO] [1673361507.511861841] [Image_Subscriber]: Image Received
# [INFO] [1673361507.570464448] [Image_Subscriber]: Image Received
# [INFO] [1673361507.637695060] [Image_Subscriber]: Image Received
# [INFO] [1673361507.697774588] [Image_Subscriber]: Image Received
# [INFO] [1673361507.760417883] [Image_Subscriber]: Image Received
# [INFO] [1673361507.837549588] [Image_Subscriber]: Image Received
# [INFO] [1673361507.903371068] [Image_Subscriber]: Image Received
# [INFO] [1673361507.962218195] [Image_Subscriber]: Image Received
# [INFO] [1673361508.030915964] [Image_Subscriber]: Image Received
# [INFO] [1673361508.079782625] [Image_Subscriber]: Image Received
# [INFO] [1673361508.156430221] [Image_Subscriber]: Image Received
# [INFO] [1673361508.237993344] [Image_Subscriber]: Image Received
# [INFO] [1673361508.350046010] [Image_Subscriber]: Image Received
# [INFO] [1673361508.463069255] [Image_Subscriber]: Image Received
# [INFO] [1673361508.555851956] [Image_Subscriber]: Image Received
# [INFO] [1673361508.650202457] [Image_Subscriber]: Image Received
# [INFO] [1673361508.803249735] [Image_Subscriber]: Image Received
# [INFO] [1673361508.904216028] [Image_Subscriber]: Image Received
# [INFO] [1673361509.039848398] [Image_Subscriber]: Image Received
# [INFO] [1673361509.095299368] [Image_Subscriber]: Image Received
# [INFO] [1673361509.174158622] [Image_Subscriber]: Image Received
# [INFO] [1673361509.262488450] [Image_Subscriber]: Image Received
# [INFO] [1673361509.339598183] [Image_Subscriber]: Image Received
# [INFO] [1673361509.383250248] [Image_Subscriber]: Image Received
# [INFO] [1673361509.462109135] [Image_Subscriber]: Image Received
# [INFO] [1673361509.602847768] [Image_Subscriber]: Image Received
# [INFO] [1673361509.728972964] [Image_Subscriber]: Image Received
# [INFO] [1673361509.846575401] [Image_Subscriber]: Image Received
# [INFO] [1673361509.922194416] [Image_Subscriber]: Image Received
# [INFO] [1673361509.970099950] [Image_Subscriber]: Image Received
# [INFO] [1673361510.037915450] [Image_Subscriber]: Image Received
# [INFO] [1673361510.075899538] [Image_Subscriber]: Image Received
# [INFO] [1673361510.168862384] [Image_Subscriber]: Image Received
# [INFO] [1673361510.268100913] [Image_Subscriber]: Image Received
# [INFO] [1673361510.344890705] [Image_Subscriber]: Image Received
# [INFO] [1673361510.410327730] [Image_Subscriber]: Image Received
# [INFO] [1673361510.459000312] [Image_Subscriber]: Image Received
# [INFO] [1673361510.498077711] [Image_Subscriber]: Image Received
# [INFO] [1673361510.542905331] [Image_Subscriber]: Image Received
# [INFO] [1673361510.608674700] [Image_Subscriber]: Image Received
# [INFO] [1673361510.660463408] [Image_Subscriber]: Image Received
# [INFO] [1673361510.722678533] [Image_Subscriber]: Image Received
# [INFO] [1673361510.761380731] [Image_Subscriber]: Image Received
# [INFO] [1673361510.812235070] [Image_Subscriber]: Image Received
# [INFO] [1673361510.849082358] [Image_Subscriber]: Image Received
# [INFO] [1673361510.899689073] [Image_Subscriber]: Image Received
# [INFO] [1673361510.936694471] [Image_Subscriber]: Image Received
# [INFO] [1673361510.972711145] [Image_Subscriber]: Image Received
# [INFO] [1673361511.021081271] [Image_Subscriber]: Image Received
# [INFO] [1673361511.062123833] [Image_Subscriber]: Image Received
# [INFO] [1673361511.139783049] [Image_Subscriber]: Image Received
# [INFO] [1673361511.206845959] [Image_Subscriber]: Image Received
# [INFO] [1673361511.289398291] [Image_Subscriber]: Image Received
# [INFO] [1673361511.374833255] [Image_Subscriber]: Image Received
# [INFO] [1673361511.431268839] [Image_Subscriber]: Image Received
# [INFO] [1673361511.491092221] [Image_Subscriber]: Image Received
# [INFO] [1673361511.555935592] [Image_Subscriber]: Image Received
# [INFO] [1673361511.662523656] [Image_Subscriber]: Image Received
# [INFO] [1673361511.743910196] [Image_Subscriber]: Image Received
# [INFO] [1673361511.818126326] [Image_Subscriber]: Image Received
# [INFO] [1673361511.867932869] [Image_Subscriber]: Image Received
# [INFO] [1673361511.935632191] [Image_Subscriber]: Image Received
# [INFO] [1673361511.980491349] [Image_Subscriber]: Image Received
# [INFO] [1673361512.056986095] [Image_Subscriber]: Image Received
# [INFO] [1673361512.115125807] [Image_Subscriber]: Image Received
# [INFO] [1673361512.151052822] [Image_Subscriber]: Image Received
# [INFO] [1673361512.217576634] [Image_Subscriber]: Image Received
# [INFO] [1673361512.258866837] [Image_Subscriber]: Image Received
# [INFO] [1673361512.323476871] [Image_Subscriber]: Image Received
# [INFO] [1673361512.392932800] [Image_Subscriber]: Image Received
# [INFO] [1673361512.461225407] [Image_Subscriber]: Image Received
# [INFO] [1673361512.523911828] [Image_Subscriber]: Image Received
# [INFO] [1673361512.573465330] [Image_Subscriber]: Image Received
# [INFO] [1673361512.648196980] [Image_Subscriber]: Image Received
# [INFO] [1673361512.726226606] [Image_Subscriber]: Image Received
# [INFO] [1673361512.766591755] [Image_Subscriber]: Image Received
# [INFO] [1673361512.848963959] [Image_Subscriber]: Image Received
# [INFO] [1673361512.899032309] [Image_Subscriber]: Image Received
# [INFO] [1673361512.944687042] [Image_Subscriber]: Image Received
# [INFO] [1673361513.018208589] [Image_Subscriber]: Image Received
# [INFO] [1673361513.093712913] [Image_Subscriber]: Image Received
# [INFO] [1673361513.148935323] [Image_Subscriber]: Image Received
# [INFO] [1673361513.234680548] [Image_Subscriber]: Image Received
# [INFO] [1673361513.293290140] [Image_Subscriber]: Image Received
# [INFO] [1673361513.374758288] [Image_Subscriber]: Image Received
# [INFO] [1673361513.444099392] [Image_Subscriber]: Image Received
# [INFO] [1673361513.503198106] [Image_Subscriber]: Image Received
# [INFO] [1673361513.575257192] [Image_Subscriber]: Image Received
# [INFO] [1673361513.640555849] [Image_Subscriber]: Image Received
# [INFO] [1673361513.697670227] [Image_Subscriber]: Image Received
# [INFO] [1673361513.743490826] [Image_Subscriber]: Image Received
# [INFO] [1673361513.830163127] [Image_Subscriber]: Image Received
# [INFO] [1673361513.927251467] [Image_Subscriber]: Image Received
# [INFO] [1673361513.973329496] [Image_Subscriber]: Image Received
# [INFO] [1673361514.036564474] [Image_Subscriber]: Image Received
# [INFO] [1673361514.116758525] [Image_Subscriber]: Image Received
# [INFO] [1673361514.163676514] [Image_Subscriber]: Image Received
# [INFO] [1673361514.248522986] [Image_Subscriber]: Image Received
# [INFO] [1673361514.313129840] [Image_Subscriber]: Image Received
# [INFO] [1673361514.362981462] [Image_Subscriber]: Image Received
# [INFO] [1673361514.456351259] [Image_Subscriber]: Image Received
# [INFO] [1673361514.546283822] [Image_Subscriber]: Image Received
# [INFO] [1673361514.632488291] [Image_Subscriber]: Image Received
# [INFO] [1673361514.689421489] [Image_Subscriber]: Image Received
# [INFO] [1673361514.756172342] [Image_Subscriber]: Image Received
# [INFO] [1673361514.824426446] [Image_Subscriber]: Image Received
# [INFO] [1673361514.874124379] [Image_Subscriber]: Image Received
# [INFO] [1673361514.932707784] [Image_Subscriber]: Image Received
# [INFO] [1673361515.022502675] [Image_Subscriber]: Image Received
# [INFO] [1673361515.056697808] [Image_Subscriber]: Image Received
# [INFO] [1673361515.150032736] [Image_Subscriber]: Image Received
# [INFO] [1673361515.231928106] [Image_Subscriber]: Image Received
# [INFO] [1673361515.280796229] [Image_Subscriber]: Image Received
# [INFO] [1673361515.360848541] [Image_Subscriber]: Image Received
# [INFO] [1673361515.419117557] [Image_Subscriber]: Image Received
# [INFO] [1673361515.481183048] [Image_Subscriber]: Image Received
# [INFO] [1673361515.546393530] [Image_Subscriber]: Image Received
# [INFO] [1673361515.616894107] [Image_Subscriber]: Image Received
# [INFO] [1673361515.733755409] [Image_Subscriber]: Image Received
# [INFO] [1673361515.792186826] [Image_Subscriber]: Image Received
# [INFO] [1673361515.852854050] [Image_Subscriber]: Image Received
# [INFO] [1673361515.893550470] [Image_Subscriber]: Image Received
# [INFO] [1673361515.961830070] [Image_Subscriber]: Image Received
# [INFO] [1673361516.020127526] [Image_Subscriber]: Image Received
# [INFO] [1673361516.065110846] [Image_Subscriber]: Image Received
# [INFO] [1673361516.134281829] [Image_Subscriber]: Image Received
# [INFO] [1673361516.218699396] [Image_Subscriber]: Image Received
# [INFO] [1673361516.261246628] [Image_Subscriber]: Image Received
# [INFO] [1673361516.413211565] [Image_Subscriber]: Image Received
# [INFO] [1673361516.518659753] [Image_Subscriber]: Image Received
# [INFO] [1673361516.623862601] [Image_Subscriber]: Image Received
# [INFO] [1673361516.725879675] [Image_Subscriber]: Image Received
# [INFO] [1673361516.808180490] [Image_Subscriber]: Image Received
# [INFO] [1673361516.917924396] [Image_Subscriber]: Image Received
# [INFO] [1673361517.009557568] [Image_Subscriber]: Image Received
# [INFO] [1673361517.090543828] [Image_Subscriber]: Image Received
# [INFO] [1673361517.187779879] [Image_Subscriber]: Image Received
# [INFO] [1673361517.286222939] [Image_Subscriber]: Image Received
# [INFO] [1673361517.367098840] [Image_Subscriber]: Image Received
# [INFO] [1673361517.491844887] [Image_Subscriber]: Image Received
# [INFO] [1673361517.595822401] [Image_Subscriber]: Image Received
# [INFO] [1673361517.700066341] [Image_Subscriber]: Image Received
# [INFO] [1673361517.803243525] [Image_Subscriber]: Image Received
# [INFO] [1673361517.907384363] [Image_Subscriber]: Image Received
# [INFO] [1673361518.006816124] [Image_Subscriber]: Image Received
# [INFO] [1673361518.085780139] [Image_Subscriber]: Image Received
# [INFO] [1673361518.166714362] [Image_Subscriber]: Image Received
# [INFO] [1673361518.278446938] [Image_Subscriber]: Image Received
# [INFO] [1673361518.406670364] [Image_Subscriber]: Image Received
# [INFO] [1673361518.537823197] [Image_Subscriber]: Image Received
# [INFO] [1673361518.630410044] [Image_Subscriber]: Image Received
# [INFO] [1673361518.730520260] [Image_Subscriber]: Image Received
# [INFO] [1673361518.821841425] [Image_Subscriber]: Image Received
# [INFO] [1673361518.905503412] [Image_Subscriber]: Image Received
# [INFO] [1673361519.021372570] [Image_Subscriber]: Image Received
# [INFO] [1673361519.117837262] [Image_Subscriber]: Image Received
# [INFO] [1673361519.198539026] [Image_Subscriber]: Image Received
# [INFO] [1673361519.283956490] [Image_Subscriber]: Image Received
# [INFO] [1673361519.407386812] [Image_Subscriber]: Image Received
# [INFO] [1673361519.523041442] [Image_Subscriber]: Image Received
# [INFO] [1673361519.609175047] [Image_Subscriber]: Image Received
# [INFO] [1673361519.695878987] [Image_Subscriber]: Image Received
# [INFO] [1673361519.818934236] [Image_Subscriber]: Image Received
# [INFO] [1673361519.929597121] [Image_Subscriber]: Image Received
# [INFO] [1673361520.023547776] [Image_Subscriber]: Image Received
# [INFO] [1673361520.103846427] [Image_Subscriber]: Image Received
# [INFO] [1673361520.178951895] [Image_Subscriber]: Image Received
# [INFO] [1673361520.274367352] [Image_Subscriber]: Image Received
# [INFO] [1673361520.351734485] [Image_Subscriber]: Image Received
# [INFO] [1673361520.474711266] [Image_Subscriber]: Image Received
# [INFO] [1673361520.564550640] [Image_Subscriber]: Image Received
# [INFO] [1673361520.666518964] [Image_Subscriber]: Image Received
# [INFO] [1673361520.771919300] [Image_Subscriber]: Image Received
# [INFO] [1673361520.869355422] [Image_Subscriber]: Image Received
# [INFO] [1673361520.950010561] [Image_Subscriber]: Image Received
# [INFO] [1673361521.063567446] [Image_Subscriber]: Image Received
# [INFO] [1673361521.143023460] [Image_Subscriber]: Image Received
# [INFO] [1673361521.228559352] [Image_Subscriber]: Image Received
# [INFO] [1673361521.292834781] [Image_Subscriber]: Image Received
# [INFO] [1673361521.367326894] [Image_Subscriber]: Image Received
# [INFO] [1673361521.454310636] [Image_Subscriber]: Image Received
# [INFO] [1673361521.539660567] [Image_Subscriber]: Image Received
# [INFO] [1673361521.662297364] [Image_Subscriber]: Image Received
# [INFO] [1673361521.747566473] [Image_Subscriber]: Image Received
# [INFO] [1673361521.858333051] [Image_Subscriber]: Image Received
# [INFO] [1673361521.944703568] [Image_Subscriber]: Image Received
# [INFO] [1673361522.029901822] [Image_Subscriber]: Image Received
# [INFO] [1673361522.090929030] [Image_Subscriber]: Image Received
# [INFO] [1673361522.171653491] [Image_Subscriber]: Image Received
# [INFO] [1673361522.237512840] [Image_Subscriber]: Image Received
# [INFO] [1673361522.289792792] [Image_Subscriber]: Image Received
# [INFO] [1673361522.362295559] [Image_Subscriber]: Image Received
# [INFO] [1673361522.434319374] [Image_Subscriber]: Image Received
# [INFO] [1673361522.489024367] [Image_Subscriber]: Image Received
# [INFO] [1673361522.587275233] [Image_Subscriber]: Image Received
# [INFO] [1673361522.668168148] [Image_Subscriber]: Image Received
# [INFO] [1673361522.765697016] [Image_Subscriber]: Image Received
# [INFO] [1673361522.875946335] [Image_Subscriber]: Image Received
# [INFO] [1673361522.962185234] [Image_Subscriber]: Image Received
# [INFO] [1673361523.056189073] [Image_Subscriber]: Image Received
# [INFO] [1673361523.177445551] [Image_Subscriber]: Image Received
# [INFO] [1673361523.276849872] [Image_Subscriber]: Image Received
# [INFO] [1673361523.367406186] [Image_Subscriber]: Image Received
# [INFO] [1673361523.453759806] [Image_Subscriber]: Image Received
# [INFO] [1673361523.563392339] [Image_Subscriber]: Image Received
# [INFO] [1673361523.684128067] [Image_Subscriber]: Image Received
# [INFO] [1673361523.750434513] [Image_Subscriber]: Image Received
# [INFO] [1673361523.832928629] [Image_Subscriber]: Image Received
# [INFO] [1673361523.900027825] [Image_Subscriber]: Image Received
# [INFO] [1673361524.026862588] [Image_Subscriber]: Image Received
# [INFO] [1673361524.098480248] [Image_Subscriber]: Image Received
# [INFO] [1673361524.165225127] [Image_Subscriber]: Image Received
# [INFO] [1673361524.261341940] [Image_Subscriber]: Image Received
# [INFO] [1673361524.357627715] [Image_Subscriber]: Image Received
# [INFO] [1673361524.468680056] [Image_Subscriber]: Image Received
# [INFO] [1673361524.551185537] [Image_Subscriber]: Image Received
# [INFO] [1673361524.634767403] [Image_Subscriber]: Image Received
# [INFO] [1673361524.706905384] [Image_Subscriber]: Image Received
# [INFO] [1673361524.808450523] [Image_Subscriber]: Image Received
# [INFO] [1673361524.893084999] [Image_Subscriber]: Image Received
# [INFO] [1673361525.006266368] [Image_Subscriber]: Image Received
# [INFO] [1673361525.159782699] [Image_Subscriber]: Image Received
# [INFO] [1673361525.271836214] [Image_Subscriber]: Image Received
# [INFO] [1673361525.384765393] [Image_Subscriber]: Image Received
# [INFO] [1673361525.558182621] [Image_Subscriber]: Image Received
# [INFO] [1673361525.653875071] [Image_Subscriber]: Image Received
# [INFO] [1673361525.789288668] [Image_Subscriber]: Image Received
# [INFO] [1673361525.933397291] [Image_Subscriber]: Image Received
# [INFO] [1673361526.029426614] [Image_Subscriber]: Image Received
# [INFO] [1673361526.153187195] [Image_Subscriber]: Image Received
# [INFO] [1673361526.283274428] [Image_Subscriber]: Image Received
# [INFO] [1673361526.339458452] [Image_Subscriber]: Image Received
# [INFO] [1673361526.376610436] [Image_Subscriber]: Image Received
# [INFO] [1673361526.463184061] [Image_Subscriber]: Image Received
# [INFO] [1673361526.518991412] [Image_Subscriber]: Image Received
# [INFO] [1673361526.564974927] [Image_Subscriber]: Image Received
# [INFO] [1673361526.640918363] [Image_Subscriber]: Image Received
# [INFO] [1673361526.711187152] [Image_Subscriber]: Image Received
# [INFO] [1673361526.757524058] [Image_Subscriber]: Image Received
# [INFO] [1673361526.800387604] [Image_Subscriber]: Image Received
# [INFO] [1673361526.821771350] [Image_Subscriber]: Image Received
# [INFO] [1673361526.872842777] [Image_Subscriber]: Image Received
# [INFO] [1673361526.948095054] [Image_Subscriber]: Image Received
# [INFO] [1673361527.007893216] [Image_Subscriber]: Image Received
# [INFO] [1673361527.041594098] [Image_Subscriber]: Image Received
# [INFO] [1673361527.131456874] [Image_Subscriber]: Image Received
# [INFO] [1673361527.182864822] [Image_Subscriber]: Image Received
# [INFO] [1673361527.285493526] [Image_Subscriber]: Image Received
# [INFO] [1673361527.353070539] [Image_Subscriber]: Image Received
# [INFO] [1673361527.421217011] [Image_Subscriber]: Image Received
# [INFO] [1673361527.464639769] [Image_Subscriber]: Image Received
# [INFO] [1673361527.514887481] [Image_Subscriber]: Image Received
# [INFO] [1673361527.561166721] [Image_Subscriber]: Image Received
# [INFO] [1673361527.640859564] [Image_Subscriber]: Image Received
# [INFO] [1673361527.690464492] [Image_Subscriber]: Image Received
# [INFO] [1673361527.760956222] [Image_Subscriber]: Image Received
# [INFO] [1673361527.844214847] [Image_Subscriber]: Image Received
# [INFO] [1673361527.901539980] [Image_Subscriber]: Image Received
# [INFO] [1673361527.952399374] [Image_Subscriber]: Image Received
# [INFO] [1673361528.021038676] [Image_Subscriber]: Image Received
# [INFO] [1673361528.071524069] [Image_Subscriber]: Image Received
# [INFO] [1673361528.153335473] [Image_Subscriber]: Image Received
# [INFO] [1673361528.214583620] [Image_Subscriber]: Image Received
# [INFO] [1673361528.269856079] [Image_Subscriber]: Image Received
# [INFO] [1673361528.336272040] [Image_Subscriber]: Image Received
# [INFO] [1673361528.372392685] [Image_Subscriber]: Image Received
# [INFO] [1673361528.462356267] [Image_Subscriber]: Image Received
# [INFO] [1673361528.522686431] [Image_Subscriber]: Image Received
# [INFO] [1673361528.575687433] [Image_Subscriber]: Image Received
# [INFO] [1673361528.642514421] [Image_Subscriber]: Image Received
# [INFO] [1673361528.702704593] [Image_Subscriber]: Image Received
# [INFO] [1673361528.763266348] [Image_Subscriber]: Image Received
# [INFO] [1673361528.840880157] [Image_Subscriber]: Image Received
# [INFO] [1673361528.903595724] [Image_Subscriber]: Image Received
# [INFO] [1673361528.948945742] [Image_Subscriber]: Image Received
# [INFO] [1673361529.005531751] [Image_Subscriber]: Image Received
# [INFO] [1673361529.059273149] [Image_Subscriber]: Image Received
# [INFO] [1673361529.133355374] [Image_Subscriber]: Image Received
# [INFO] [1673361529.182939498] [Image_Subscriber]: Image Received
# [INFO] [1673361529.255104373] [Image_Subscriber]: Image Received
# [INFO] [1673361529.319611673] [Image_Subscriber]: Image Received
# [INFO] [1673361529.369141912] [Image_Subscriber]: Image Received
# [INFO] [1673361529.410553592] [Image_Subscriber]: Image Received
# [INFO] [1673361529.447500068] [Image_Subscriber]: Image Received
# [INFO] [1673361529.511893168] [Image_Subscriber]: Image Received
# [INFO] [1673361529.562790947] [Image_Subscriber]: Image Received
# [INFO] [1673361529.644563171] [Image_Subscriber]: Image Received
# [INFO] [1673361529.710211565] [Image_Subscriber]: Image Received
# [INFO] [1673361529.745784836] [Image_Subscriber]: Image Received
# [INFO] [1673361529.812766027] [Image_Subscriber]: Image Received
# [INFO] [1673361529.855093663] [Image_Subscriber]: Image Received
# [INFO] [1673361529.961410353] [Image_Subscriber]: Image Received
# [INFO] [1673361530.025024062] [Image_Subscriber]: Image Received
# [INFO] [1673361530.067384652] [Image_Subscriber]: Image Received
# [INFO] [1673361530.191668248] [Image_Subscriber]: Image Received
# [INFO] [1673361530.295775751] [Image_Subscriber]: Image Received
# [INFO] [1673361530.389416498] [Image_Subscriber]: Image Received
# [INFO] [1673361530.549834995] [Image_Subscriber]: Image Received
# [INFO] [1673361530.637012213] [Image_Subscriber]: Image Received
# [INFO] [1673361530.699058458] [Image_Subscriber]: Image Received
# [INFO] [1673361530.842121965] [Image_Subscriber]: Image Received
# [INFO] [1673361530.972300147] [Image_Subscriber]: Image Received
# [INFO] [1673361531.084958017] [Image_Subscriber]: Image Received
# [INFO] [1673361531.194776168] [Image_Subscriber]: Image Received
# [INFO] [1673361531.286526232] [Image_Subscriber]: Image Received
# [INFO] [1673361531.426580283] [Image_Subscriber]: Image Received
# [INFO] [1673361531.551541931] [Image_Subscriber]: Image Received
# [INFO] [1673361531.670192076] [Image_Subscriber]: Image Received
# [INFO] [1673361531.756580678] [Image_Subscriber]: Image Received
# [INFO] [1673361531.871088730] [Image_Subscriber]: Image Received
# [INFO] [1673361531.963427039] [Image_Subscriber]: Image Received
# [INFO] [1673361532.091637649] [Image_Subscriber]: Image Received
# [INFO] [1673361532.221801966] [Image_Subscriber]: Image Received
# [INFO] [1673361532.330509200] [Image_Subscriber]: Image Received
# [INFO] [1673361532.458751047] [Image_Subscriber]: Image Received
# [INFO] [1673361532.541573051] [Image_Subscriber]: Image Received
# [INFO] [1673361532.630518181] [Image_Subscriber]: Image Received
# [INFO] [1673361532.706015890] [Image_Subscriber]: Image Received
# [INFO] [1673361532.807151958] [Image_Subscriber]: Image Received
# [INFO] [1673361532.918363195] [Image_Subscriber]: Image Received
# [INFO] [1673361533.006907089] [Image_Subscriber]: Image Received
# [INFO] [1673361533.116057789] [Image_Subscriber]: Image Received
# [INFO] [1673361533.238320244] [Image_Subscriber]: Image Received
# [INFO] [1673361533.338242816] [Image_Subscriber]: Image Received
# [INFO] [1673361533.469168837] [Image_Subscriber]: Image Received
# [INFO] [1673361533.576093522] [Image_Subscriber]: Image Received
# [INFO] [1673361533.711129491] [Image_Subscriber]: Image Received
# [INFO] [1673361533.833883043] [Image_Subscriber]: Image Received
# [INFO] [1673361533.939099845] [Image_Subscriber]: Image Received
# [INFO] [1673361534.051033544] [Image_Subscriber]: Image Received
# [INFO] [1673361534.146366811] [Image_Subscriber]: Image Received
# [INFO] [1673361534.245914232] [Image_Subscriber]: Image Received
# [INFO] [1673361534.378351709] [Image_Subscriber]: Image Received
# [INFO] [1673361534.488327219] [Image_Subscriber]: Image Received
# [INFO] [1673361534.617985555] [Image_Subscriber]: Image Received
# [INFO] [1673361534.739242093] [Image_Subscriber]: Image Received
# [INFO] [1673361534.843895831] [Image_Subscriber]: Image Received
# [INFO] [1673361534.969875680] [Image_Subscriber]: Image Received
# [INFO] [1673361535.072670429] [Image_Subscriber]: Image Received
# [INFO] [1673361535.223089376] [Image_Subscriber]: Image Received
# [INFO] [1673361535.340285544] [Image_Subscriber]: Image Received
# [INFO] [1673361535.437678714] [Image_Subscriber]: Image Received
# [INFO] [1673361535.504295308] [Image_Subscriber]: Image Received
# [INFO] [1673361535.611630590] [Image_Subscriber]: Image Received
# [INFO] [1673361535.676755712] [Image_Subscriber]: Image Received
# [INFO] [1673361535.775093689] [Image_Subscriber]: Image Received
# [INFO] [1673361535.919120847] [Image_Subscriber]: Image Received
# [INFO] [1673361536.039056831] [Image_Subscriber]: Image Received
# [INFO] [1673361536.119924809] [Image_Subscriber]: Image Received
# [INFO] [1673361536.162730261] [Image_Subscriber]: Image Received
# [INFO] [1673361536.306285947] [Image_Subscriber]: Image Received
# [INFO] [1673361536.433237422] [Image_Subscriber]: Image Received
# [INFO] [1673361536.521076567] [Image_Subscriber]: Image Received
# [INFO] [1673361536.609436803] [Image_Subscriber]: Image Received
# [INFO] [1673361536.697186782] [Image_Subscriber]: Image Received
# [INFO] [1673361536.794393199] [Image_Subscriber]: Image Received
# [INFO] [1673361536.937631772] [Image_Subscriber]: Image Received
# [INFO] [1673361537.028818900] [Image_Subscriber]: Image Received
# [INFO] [1673361537.161774979] [Image_Subscriber]: Image Received
# [INFO] [1673361537.259469976] [Image_Subscriber]: Image Received
# [INFO] [1673361537.347532290] [Image_Subscriber]: Image Received
# [INFO] [1673361537.408403232] [Image_Subscriber]: Image Received
# [INFO] [1673361537.454117949] [Image_Subscriber]: Image Received
# [INFO] [1673361537.532110109] [Image_Subscriber]: Image Received
# [INFO] [1673361537.571067452] [Image_Subscriber]: Image Received
# [INFO] [1673361537.637881642] [Image_Subscriber]: Image Received
# [INFO] [1673361537.672662310] [Image_Subscriber]: Image Received
# [INFO] [1673361537.735998712] [Image_Subscriber]: Image Received
# [INFO] [1673361537.786815255] [Image_Subscriber]: Image Received
# [INFO] [1673361537.891923814] [Image_Subscriber]: Image Received
# [INFO] [1673361537.962500724] [Image_Subscriber]: Image Received
# [INFO] [1673361538.038047295] [Image_Subscriber]: Image Received
# [INFO] [1673361538.089069626] [Image_Subscriber]: Image Received
# [INFO] [1673361538.156764617] [Image_Subscriber]: Image Received
# [INFO] [1673361538.217972356] [Image_Subscriber]: Image Received
# [INFO] [1673361538.256241889] [Image_Subscriber]: Image Received
# [INFO] [1673361538.319573000] [Image_Subscriber]: Image Received
# [INFO] [1673361538.366157889] [Image_Subscriber]: Image Received
# [INFO] [1673361538.438718685] [Image_Subscriber]: Image Received
# [INFO] [1673361538.469620428] [Image_Subscriber]: Image Received
# [INFO] [1673361538.533273692] [Image_Subscriber]: Image Received
# [INFO] [1673361538.585649228] [Image_Subscriber]: Image Received
# [INFO] [1673361538.661390373] [Image_Subscriber]: Image Received
# [INFO] [1673361538.729020314] [Image_Subscriber]: Image Received
# [INFO] [1673361538.772938531] [Image_Subscriber]: Image Received
# [INFO] [1673361538.847904883] [Image_Subscriber]: Image Received
# [INFO] [1673361538.908391242] [Image_Subscriber]: Image Received
# [INFO] [1673361538.952862742] [Image_Subscriber]: Image Received
# [INFO] [1673361539.027876956] [Image_Subscriber]: Image Received
# [INFO] [1673361539.067155423] [Image_Subscriber]: Image Received
# [INFO] [1673361539.154575657] [Image_Subscriber]: Image Received
# [INFO] [1673361539.214600913] [Image_Subscriber]: Image Received
# [INFO] [1673361539.258113794] [Image_Subscriber]: Image Received
# [INFO] [1673361539.364102521] [Image_Subscriber]: Image Received
# [INFO] [1673361539.440242567] [Image_Subscriber]: Image Received
# [INFO] [1673361539.522389045] [Image_Subscriber]: Image Received
# [INFO] [1673361539.555389221] [Image_Subscriber]: Image Received
# [INFO] [1673361539.617875511] [Image_Subscriber]: Image Received
# [INFO] [1673361539.662495745] [Image_Subscriber]: Image Received
# [INFO] [1673361539.745260627] [Image_Subscriber]: Image Received
# [INFO] [1673361539.804597726] [Image_Subscriber]: Image Received
# [INFO] [1673361539.851733589] [Image_Subscriber]: Image Received
# [INFO] [1673361539.923755668] [Image_Subscriber]: Image Received
# [INFO] [1673361539.973558495] [Image_Subscriber]: Image Received
# [INFO] [1673361540.071994753] [Image_Subscriber]: Image Received
# [INFO] [1673361540.197853654] [Image_Subscriber]: Image Received
# [INFO] [1673361540.298331843] [Image_Subscriber]: Image Received
# [INFO] [1673361540.351241106] [Image_Subscriber]: Image Received
# [INFO] [1673361540.413408036] [Image_Subscriber]: Image Received
# [INFO] [1673361540.446412073] [Image_Subscriber]: Image Received
# [INFO] [1673361540.495130270] [Image_Subscriber]: Closing stream window..
# [INFO] [1673361540.540223932] [Image_Subscriber]: Image Received
# [INFO] [1673361540.586688820] [Image_Subscriber]: Image Received
# [INFO] [1673361540.619159641] [Image_Subscriber]: Image Received
# [INFO] [1673361540.657526300] [Image_Subscriber]: Image Received
# [INFO] [1673361540.700940098] [Image_Subscriber]: Image Received
# [INFO] [1673361540.737082086] [Image_Subscriber]: Image Received
# [INFO] [1673361540.780324635] [Image_Subscriber]: Image Received
# [INFO] [1673361540.826593767] [Image_Subscriber]: Image Received
# [INFO] [1673361540.888437498] [Image_Subscriber]: Image Received
# [INFO] [1673361540.941240876] [Image_Subscriber]: Image Received
# [INFO] [1673361540.989920784] [Image_Subscriber]: Image Received
# [INFO] [1673361541.036932214] [Image_Subscriber]: Image Received
# [INFO] [1673361541.089094205] [Image_Subscriber]: Image Received
# [INFO] [1673361541.140419191] [Image_Subscriber]: Image Received
# [INFO] [1673361541.196700946] [Image_Subscriber]: Image Received
# [INFO] [1673361541.251248304] [Image_Subscriber]: Image Received
# [INFO] [1673361541.307383529] [Image_Subscriber]: Image Received
# [INFO] [1673361541.350993303] [Image_Subscriber]: Image Received
# [INFO] [1673361541.392958462] [Image_Subscriber]: Image Received
# [INFO] [1673361541.470898886] [Image_Subscriber]: Image Received
# [INFO] [1673361541.523546922] [Image_Subscriber]: Image Received
# [INFO] [1673361541.562263859] [Image_Subscriber]: Image Received
# [INFO] [1673361541.640081532] [Image_Subscriber]: Image Received
# [INFO] [1673361541.701467772] [Image_Subscriber]: Image Received
# [INFO] [1673361541.785927547] [Image_Subscriber]: Image Received
# [INFO] [1673361541.880148800] [Image_Subscriber]: Image Received
# [INFO] [1673361541.957324207] [Image_Subscriber]: Image Received
# [INFO] [1673361542.040827635] [Image_Subscriber]: Image Received
# [INFO] [1673361542.084585335] [Image_Subscriber]: Image Received
# [INFO] [1673361542.125267874] [Image_Subscriber]: Image Received
# [INFO] [1673361542.223878746] [Image_Subscriber]: Image Received
# [INFO] [1673361542.282050094] [Image_Subscriber]: Image Received
# [INFO] [1673361542.366110189] [Image_Subscriber]: Image Received
# [INFO] [1673361542.418327284] [Image_Subscriber]: Image Received
# [INFO] [1673361542.486449235] [Image_Subscriber]: Image Received
# [INFO] [1673361542.523749841] [Image_Subscriber]: Image Received
# [INFO] [1673361542.595991771] [Image_Subscriber]: Image Received
# [INFO] [1673361542.676607490] [Image_Subscriber]: Image Received
# [INFO] [1673361542.726184507] [Image_Subscriber]: Image Received
# [INFO] [1673361542.818451481] [Image_Subscriber]: Image Received
# [INFO] [1673361542.947805999] [Image_Subscriber]: Image Received
# [INFO] [1673361543.001051949] [Image_Subscriber]: Image Received
# [INFO] [1673361543.048255111] [Image_Subscriber]: Image Received
# [INFO] [1673361543.122903830] [Image_Subscriber]: Image Received
# [INFO] [1673361543.184796519] [Image_Subscriber]: Image Received
# [INFO] [1673361543.260160238] [Image_Subscriber]: Image Received
# [INFO] [1673361543.329955160] [Image_Subscriber]: Image Received
# [INFO] [1673361543.402409840] [Image_Subscriber]: Image Received
# [INFO] [1673361543.435801414] [Image_Subscriber]: Image Received
# [INFO] [1673361543.519414763] [Image_Subscriber]: Image Received
# [INFO] [1673361543.570696099] [Image_Subscriber]: Image Received
# [INFO] [1673361543.635691752] [Image_Subscriber]: Image Received
# [INFO] [1673361543.695553707] [Image_Subscriber]: Image Received
# [INFO] [1673361543.776903828] [Image_Subscriber]: Image Received
# [INFO] [1673361543.870697655] [Image_Subscriber]: Image Received
# [INFO] [1673361543.919841107] [Image_Subscriber]: Image Received
# [INFO] [1673361543.987039643] [Image_Subscriber]: Image Received
# [INFO] [1673361544.109692937] [Image_Subscriber]: Image Received
# [INFO] [1673361544.147090592] [Image_Subscriber]: Image Received
# [INFO] [1673361544.228974370] [Image_Subscriber]: Image Received
# [INFO] [1673361544.300824314] [Image_Subscriber]: Image Received
# [INFO] [1673361544.355982662] [Image_Subscriber]: Image Received
# [INFO] [1673361544.471077597] [Image_Subscriber]: Image Received
# [INFO] [1673361544.541046311] [Image_Subscriber]: Image Received
# [INFO] [1673361544.605145361] [Image_Subscriber]: Image Received
# [INFO] [1673361544.678516675] [Image_Subscriber]: Image Received
# [INFO] [1673361544.760897608] [Image_Subscriber]: Image Received
# [INFO] [1673361544.884952965] [Image_Subscriber]: Image Received
# [INFO] [1673361544.948355249] [Image_Subscriber]: Image Received
# [INFO] [1673361545.045189508] [Image_Subscriber]: Image Received
# [INFO] [1673361545.139240026] [Image_Subscriber]: Image Received
# [INFO] [1673361545.201194089] [Image_Subscriber]: Image Received
# [INFO] [1673361545.327821792] [Image_Subscriber]: Image Received
# [INFO] [1673361545.409288681] [Image_Subscriber]: Image Received
# [INFO] [1673361545.472590491] [Image_Subscriber]: Image Received
# [INFO] [1673361545.559760828] [Image_Subscriber]: Image Received
# [INFO] [1673361545.682608477] [Image_Subscriber]: Image Received
# [INFO] [1673361545.811568668] [Image_Subscriber]: Image Received
# [INFO] [1673361545.892992609] [Image_Subscriber]: Image Received
# [INFO] [1673361545.992432405] [Image_Subscriber]: Image Received
# [INFO] [1673361546.079125618] [Image_Subscriber]: Image Received
# [INFO] [1673361546.170891944] [Image_Subscriber]: Image Received
# [INFO] [1673361546.334517910] [Image_Subscriber]: Image Received
# [INFO] [1673361546.440511395] [Image_Subscriber]: Image Received
# [INFO] [1673361546.498981036] [Image_Subscriber]: Image Received
# [INFO] [1673361546.619691731] [Image_Subscriber]: Image Received
# [INFO] [1673361546.718290331] [Image_Subscriber]: Image Received
# [INFO] [1673361546.831728045] [Image_Subscriber]: Image Received
# [INFO] [1673361546.904843361] [Image_Subscriber]: Image Received
# [INFO] [1673361547.010897926] [Image_Subscriber]: Image Received
# [INFO] [1673361547.158423294] [Image_Subscriber]: Image Received
# [INFO] [1673361547.218964268] [Image_Subscriber]: Image Received
# [INFO] [1673361547.289630990] [Image_Subscriber]: Image Received
# [INFO] [1673361547.424980306] [Image_Subscriber]: Image Received
# [INFO] [1673361547.499648937] [Image_Subscriber]: Image Received
# [INFO] [1673361547.618634983] [Image_Subscriber]: Image Received
# [INFO] [1673361547.685951783] [Image_Subscriber]: Image Received
# [INFO] [1673361547.776423135] [Image_Subscriber]: Image Received
# [INFO] [1673361547.829050556] [Image_Subscriber]: Image Received
# [INFO] [1673361547.954446688] [Image_Subscriber]: Image Received
# [INFO] [1673361548.051127262] [Image_Subscriber]: Image Received
# [INFO] [1673361548.117566704] [Image_Subscriber]: Image Received
# [INFO] [1673361548.265844461] [Image_Subscriber]: Image Received
# [INFO] [1673361548.349377444] [Image_Subscriber]: Image Received
# [INFO] [1673361548.493197176] [Image_Subscriber]: Image Received
# [INFO] [1673361548.602767765] [Image_Subscriber]: Image Received
# [INFO] [1673361548.672773922] [Image_Subscriber]: Image Received
# [INFO] [1673361548.747407135] [Image_Subscriber]: Image Received
# [INFO] [1673361548.818457387] [Image_Subscriber]: Image Received
# [INFO] [1673361548.883857646] [Image_Subscriber]: Image Received
# [INFO] [1673361549.065284965] [Image_Subscriber]: Image Received
# [INFO] [1673361549.150533010] [Image_Subscriber]: Image Received
# [INFO] [1673361549.260294251] [Image_Subscriber]: Image Received
# [INFO] [1673361549.321689940] [Image_Subscriber]: Image Received
# [INFO] [1673361549.384315884] [Image_Subscriber]: Image Received
# [INFO] [1673361549.477385562] [Image_Subscriber]: Image Received
# [INFO] [1673361549.551061641] [Image_Subscriber]: Image Received
# [INFO] [1673361549.671672635] [Image_Subscriber]: Image Received
# [INFO] [1673361549.742377039] [Image_Subscriber]: Image Received
# [INFO] [1673361549.794087007] [Image_Subscriber]: Image Received
# [INFO] [1673361549.885961248] [Image_Subscriber]: Image Received
# [INFO] [1673361549.929439419] [Image_Subscriber]: Image Received
# [INFO] [1673361550.032608306] [Image_Subscriber]: Image Received
# [INFO] [1673361550.113754961] [Image_Subscriber]: Image Received
# [INFO] [1673361550.219935352] [Image_Subscriber]: Image Received
# [INFO] [1673361550.293555123] [Image_Subscriber]: Image Received
# [INFO] [1673361550.410657071] [Image_Subscriber]: Image Received
# [INFO] [1673361550.522189940] [Image_Subscriber]: Image Received
# [INFO] [1673361550.628661831] [Image_Subscriber]: Image Received
# [INFO] [1673361550.687951558] [Image_Subscriber]: Image Received
# [INFO] [1673361550.801884288] [Image_Subscriber]: Image Received
# [INFO] [1673361550.878319566] [Image_Subscriber]: Image Received
# [INFO] [1673361550.988187450] [Image_Subscriber]: Image Received
# [INFO] [1673361551.042176201] [Image_Subscriber]: Image Received
# [INFO] [1673361551.115087012] [Image_Subscriber]: Image Received
# [INFO] [1673361551.171103674] [Image_Subscriber]: Image Received
# [INFO] [1673361551.293675083] [Image_Subscriber]: Image Received
# [INFO] [1673361551.365494159] [Image_Subscriber]: Image Received
# [INFO] [1673361551.447595875] [Image_Subscriber]: Image Received
# [INFO] [1673361551.607314000] [Image_Subscriber]: Image Received
# [INFO] [1673361551.668774309] [Image_Subscriber]: Image Received
# [INFO] [1673361551.736843889] [Image_Subscriber]: Image Received
# [INFO] [1673361551.868945685] [Image_Subscriber]: Image Received
# [INFO] [1673361551.892247997] [Image_Subscriber]: Image Received
# [INFO] [1673361552.053120020] [Image_Subscriber]: Image Received
# [INFO] [1673361552.120411133] [Image_Subscriber]: Image Received
# [INFO] [1673361552.182299564] [Image_Subscriber]: Image Received
# [INFO] [1673361552.252184465] [Image_Subscriber]: Image Received
# [INFO] [1673361552.338079667] [Image_Subscriber]: Image Received
# [INFO] [1673361552.435997555] [Image_Subscriber]: Image Received
# [INFO] [1673361552.597883288] [Image_Subscriber]: Image Received
# [INFO] [1673361552.662173235] [Image_Subscriber]: Image Received
# [INFO] [1673361552.720017244] [Image_Subscriber]: Image Received
# [INFO] [1673361552.840199637] [Image_Subscriber]: Image Received
# [INFO] [1673361552.927894576] [Image_Subscriber]: Image Received
# [INFO] [1673361553.018333253] [Image_Subscriber]: Image Received
# [INFO] [1673361553.122570824] [Image_Subscriber]: Image Received
# [INFO] [1673361553.232536501] [Image_Subscriber]: Image Received
# [INFO] [1673361553.332029817] [Image_Subscriber]: Image Received
# [INFO] [1673361553.405249855] [Image_Subscriber]: Image Received
# [INFO] [1673361553.460917984] [Image_Subscriber]: Image Received
# [INFO] [1673361553.528029169] [Image_Subscriber]: Image Received
# [INFO] [1673361553.638072137] [Image_Subscriber]: Image Received
# [INFO] [1673361553.685732060] [Image_Subscriber]: Image Received
# [INFO] [1673361553.749541734] [Image_Subscriber]: Image Received
# [INFO] [1673361553.808181243] [Image_Subscriber]: Image Received
# [INFO] [1673361553.884008019] [Image_Subscriber]: Image Received
# [INFO] [1673361553.956844254] [Image_Subscriber]: Image Received
# [INFO] [1673361554.022813730] [Image_Subscriber]: Image Received
# [INFO] [1673361554.109807722] [Image_Subscriber]: Image Received
# [INFO] [1673361554.158142509] [Image_Subscriber]: Image Received
# [INFO] [1673361554.234316582] [Image_Subscriber]: Image Received
# [INFO] [1673361554.342379600] [Image_Subscriber]: Image Received
# [INFO] [1673361554.468995184] [Image_Subscriber]: Image Received
# [INFO] [1673361554.534470825] [Image_Subscriber]: Image Received
# [INFO] [1673361554.628648952] [Image_Subscriber]: Image Received
# [INFO] [1673361554.765772104] [Image_Subscriber]: Image Received
# [INFO] [1673361554.828754763] [Image_Subscriber]: Image Received
# [INFO] [1673361554.917496150] [Image_Subscriber]: Image Received
# [INFO] [1673361554.984870962] [Image_Subscriber]: Image Received
# [INFO] [1673361555.079478283] [Image_Subscriber]: Image Received
# [INFO] [1673361555.137347259] [Image_Subscriber]: Image Received
# [INFO] [1673361555.253193245] [Image_Subscriber]: Image Received
# [INFO] [1673361555.331324901] [Image_Subscriber]: Image Received
# [INFO] [1673361555.408693582] [Image_Subscriber]: Image Received
# [INFO] [1673361555.521603561] [Image_Subscriber]: Image Received
# [INFO] [1673361555.590230533] [Image_Subscriber]: Image Received
# [INFO] [1673361555.706141595] [Image_Subscriber]: Image Received
# [INFO] [1673361555.762691984] [Image_Subscriber]: Image Received
# [INFO] [1673361555.824982378] [Image_Subscriber]: Image Received
# [INFO] [1673361555.890286487] [Image_Subscriber]: Image Received
# [INFO] [1673361556.026073275] [Image_Subscriber]: Image Received
# [INFO] [1673361556.134667549] [Image_Subscriber]: Image Received
# [INFO] [1673361556.192135579] [Image_Subscriber]: Image Received
# [INFO] [1673361556.334993499] [Image_Subscriber]: Image Received
# [INFO] [1673361556.407645709] [Image_Subscriber]: Image Received
# [INFO] [1673361556.476596878] [Image_Subscriber]: Image Received
# [INFO] [1673361556.579777629] [Image_Subscriber]: Image Received
# [INFO] [1673361556.662904155] [Image_Subscriber]: Image Received
# [INFO] [1673361556.731218943] [Image_Subscriber]: Image Received
# [INFO] [1673361556.794042308] [Image_Subscriber]: Image Received
# [INFO] [1673361556.877209101] [Image_Subscriber]: Image Received
# [INFO] [1673361556.954226722] [Image_Subscriber]: Image Received
# [INFO] [1673361557.055674902] [Image_Subscriber]: Image Received
# [INFO] [1673361557.102093288] [Image_Subscriber]: Image Received
# [INFO] [1673361557.226778416] [Image_Subscriber]: Image Received
# [INFO] [1673361557.336562186] [Image_Subscriber]: Image Received
# [INFO] [1673361557.473546375] [Image_Subscriber]: Image Received
# [INFO] [1673361557.542800307] [Image_Subscriber]: Image Received
# [INFO] [1673361557.611722653] [Image_Subscriber]: Image Received
# [INFO] [1673361557.677992214] [Image_Subscriber]: Image Received
# [INFO] [1673361557.787195901] [Image_Subscriber]: Image Received
# [INFO] [1673361557.855364099] [Image_Subscriber]: Image Received
# [INFO] [1673361557.960284292] [Image_Subscriber]: Image Received
# [INFO] [1673361558.051102689] [Image_Subscriber]: Image Received
# [INFO] [1673361558.121235601] [Image_Subscriber]: Image Received
# [INFO] [1673361558.252012896] [Image_Subscriber]: Image Received
# [INFO] [1673361558.321420949] [Image_Subscriber]: Image Received
# [INFO] [1673361558.442331156] [Image_Subscriber]: Image Received
# [INFO] [1673361558.526625744] [Image_Subscriber]: Image Received
# [INFO] [1673361567.243045157] [Image_Subscriber]: Stopping the stream ...

# %%
quit()
